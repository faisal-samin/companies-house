# %% [markdown]
# # Enriching Companies House data

# %% [markdown]
# ![title](Images/ch_screenshot.png)

# %% [markdown]
# This notebook gives an overview on how business data from Companies House is imported, formatting and then enriched by exploiting various APIs and websites. Examples of applications include:
# -  Retrieving official company websites using Google Places API
# -  Scraping websites to get keywords to classify the industry of businesses.
# -  Obtaining social media accounts and handles for companies and then use these to get a proxy for their web presence (number of followers, likes etc.)

# %% [markdown]
# ## Importing data

# %% [markdown]
# The Free Company Data Product is a downloadable data snapshot containing basic company data of live companies on the Companies House register, and is the principal dataset for this project. This is updated monthly and needs to be downloaded before importing as a pandas dataframe. First, we need to import some modules...

# %% [markdown]
# ### Modules

# %% [markdown]
# -  Pandas: provide easy-to-use data structures in Python
# -  Numpy: provides fast and efficient multidimensional arrays, in addition to linear algebra and mathematical operations.
# -  Matplotlib: provides plot to visualise data

# %%
import pandas as pd
from pandas import DataFrame, Series
import numpy as np

import matplotlib.pyplot as plt
# Increase figure and font sizes for easier viewing
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14

# %% [markdown]
# ### Loading and formatting Companies House dataset

# %% [markdown]
# The latest version of the Free Company Data Product can be downloaded here. http://download.companieshouse.gov.uk/en_output.html. The zip file that is downloaded is approximately 300MB, and the raw CSV file around 2GB. Once downloaded, ensure that the data is saved in the root folder of this notebook (or amend directory as required).

# %%
# to-do: investigate warning on mixed data types
ch_raw = pd.read_csv('/Users/dataexploitationmac1/Desktop/Faisal/Datasets/BasicCompanyDataAsOneFile-2018-02-01.csv')
# ch_raw = pd.read_csv('/Users/fasamin/Desktop/DS/Datasets/BasicCompanyDataAsOneFile-2018-02-01.csv')

# %%
# preview the data
ch_raw.head(10) # first 10 rows

# %%
# fields available
ch_raw.columns

# %%
# remove unnecessary columns for this project
# why is copy() used? See explanation at link below:
# https://stackoverflow.com/questions/27673231/why-should-i-make-a-copy-of-a-data-frame-in-pandas
ch = ch_raw.iloc[:,[0,1,4,5,6,7,8,9,10,11,12,18,19,21,26,27,28,29]].copy()

# rename columns
ch.columns = ['name','crn','address1','address2','postTown','county','country', \
            'postcode','category','status','origin','accounts_lastMadeUpDate','accountCategory',\
            'returns_lastMadeUpDate','sic1','sic2','sic3','sic4']

# %%
# format missing values
ch.sic1.replace('None Supplied', np.NaN, inplace=True)
ch = ch.dropna(subset=['name']) # delete rows with null business names (usually only a few values)

# %%
# Produce a range of key stats 
# Key stats
print('---------')
print('Number of businesses: %s' %len(ch))
print('Missing SIC codes: %s' %ch.sic1.isnull().sum())
sic_comp = (1.0 - (float(ch.sic1.isnull().sum())/len(ch)))*100
print('SIC code completion: %.2f' %sic_comp + '%')
post_comp = (1.0 - (float(ch.postcode.isnull().sum())/len(ch)))*100
print('Postcode completion: %.2f' %post_comp + '%')
print('---------')
print('Category breakdown (top 5)')
print('')
print(ch.category.value_counts().head())
print('---------')
print('Account category (top 5)')
print('')
print(ch.accountCategory.value_counts().head())
print('---------')
print('Geographical breakdown (top 5)')
print('')
print(ch.origin.value_counts().head())
print('---------')
print('SIC code breakdown (top 5)')
print('')
print(ch.sic1.value_counts().head())

# %% [markdown]
# ### Data exploration

# %% [markdown]
# Some pandas commands to explore the dataset, including setting up a function to find companies.

# %%
ch.dtypes # types of each column - all objects

# %%
def find_company(name):
    '''
    Searches companies house dataset for company name which include the given input which must be a string.
    '''
    name = name.lower()
    n = ch.name.str.lower().str.contains(name)
    x = input(str(n.sum()) + ' companies found. See list of companies? Y or N? ')
    if x.lower() == 'y':
        return ch[n]
    else:
        return True

# %%
find_company('Burberry') # testing function on a few cases

# %%
find_company('Dyson')

# %% [markdown]
# Exploring SIC codes...

# %%
ch.sic1.describe() # counts occurences and unique values

# %% [markdown]
# Sorting by the top 20 SIC codes shows that some of these are not very descriptive. Top of the list is 'Other business support service activities n.e.c'. Third is 'Dormant Company' and this is followed by 'Other service activities n.e.c'.

# %%
ch.sic1.value_counts().head(20) # sort by top 20 sic codes

# %%
ch.sic1.value_counts().head(30).plot() # shows skew of top categories
plt.show()

# %% [markdown]
# Checking if company reference numbers are unique

# %%
ch.crn.describe() # all crns are unique

# %%
ch.crn.isnull().sum() # 0

# %% [markdown]
# Exploring the address data

# %%
ch.head() # reminder of the address fields

# %%
ch.address1.describe() # 1.6 million unique address

# %%
ch.address1.isnull().sum() # 27K null addresses

# %%
ch.postTown.isnull().sum() # 93K missing town names

# %%
ch.postcode.isnull().sum() # 52K missing post codes

# %% [markdown]
# ### Export formatted dataset

# %%
# Export dataset, named after MMYY of ch data
ch.to_csv('ch_2018-02.csv',index=False)

# %% [markdown]
# Optional: remove non-UK companies

# %%
ch_uk = ch[ch['origin'].isin(['United Kingdom','Great Britain','UNITED KINGDOM','GREAT BRITAIN','ENGLAND & WALES','UK'])]
ch_uk.reset_index(inplace=True)
ch_uk.to_csv('ch_2018-02_uk.csv',index=False)

# %% [markdown]
# ## Scraping data from Google Search Results

# %% [markdown]
# This section goes through the process of running google searches of business names in Companies House, scraping text from the results, and then returning a wordcloud of text from the first page of results.
#
# The code below builds up the code for functions that run searches and produce
# worldclouds as follows:
#
# cloud(keyWords(search('Company Name')))
#
# - search(string): returns a list of URLs from Google for the given term
# - keyWords(list): screen-scrapes all visible text from the given list of URLs, and cleans
# - cloud(string): after removing a given list of stopwords, produces a wordcloud

# %% [markdown]
# ### Importing further modules and data

# %%
import webbrowser # to open web links
import nltk # natural language toolkit
from nltk.corpus import stopwords # Import the stop word list, may require download
# WordCloud modules
from wordcloud import WordCloud, STOPWORDS

import re # regular expressions 
from time import sleep # to pause web-scraper
import requests # allows you to send HTTP requests via Python
from bs4 import BeautifulSoup # beautiful soup for parsing of HTML

# %% [markdown]
# Read in formatted CH dataset if starting a new session. We'll refer to this at the end of the section after we've built up our tools to scrape and clean website text.

# %%
ch = pd.read_csv('ch_2018-02.csv')

# %% [markdown]
# ### Returning links for a Google Search term

# %% [markdown]
# First, we need to build some functionality to scrape the search results returned by Google.

# %%
# Set business search term as an example
biz = 'DYSON LIMITED'

# %%
# Read HTML
html = requests.get('https://www.google.co.uk/search?q='+ biz)
# Parse HTML into a BeautifulSoup object
soup = BeautifulSoup(html.content, 'html5lib')

# %%
# Get all links and put into list
list_of_links = []
for link in soup.find_all('a'):
    list_of_links.append(link.get('href'))

# %%
print(list_of_links) # needs cleaning up

# %%
# Cleaning up results
links = DataFrame({'urls':list_of_links}) #turn list into DF
links = links[links.urls.str.contains('/url?')] #Only search results

# %%
# remove cached sites
links = links[links.urls.str.contains('webcache.googleusercontent') == False]

# %%
# remove opening url?q= string
links = links.urls.str.replace('/url\?q=',"")
# after this, you don't need to call list anymore on the column

# %%
# remove suffixed &sa bit by splitting and drop index
links = links.str.split('&sa',1).reset_index().drop('index',1)
# this is now a dataframe

# %%
# use iterrows to grab first entry in each list which should be the working url
links_cleaned = []
for row in links.iterrows():
    links_cleaned.append(row[1][0][0])

# %%
# convert to dataframe
links_cleaned = DataFrame(links_cleaned)

# %% [markdown]
# We can now bring this together in one function. Note that we're screen-scraping from Google Search results so we'll need to be careful to not overload Google with search requests in quick succession (and potentially get our IP blocked).

# %%
def search_google(business_name):
    '''
    Takes in a business name and returns the links returned in the first page of Google Search results
    '''
    # Read HTML
    html = requests.get('https://www.google.co.uk/search?q='+business_name)
    # Parse HTML into a BeautifulSoup object
    soup = BeautifulSoup(html.content, 'html5lib')

    # Get all links and put into list
    list_of_links = []
    for link in soup.find_all('a'):
        list_of_links.append(link.get('href'))

    # Cleaning up results
    links = DataFrame({'urls':list_of_links}) #turn list into DF
    links = links[links.urls.str.contains('/url?')] #Only search results
    
    # remove cached sites
    links = links[links.urls.str.contains('webcache.googleusercontent') == False]

    # remove opening url?q= string
    links = links.urls.str.replace('/url\?q=',"")
    # after this, you don't need to call list anymore on the column

    # remove suffixed &sa bit by splitting and drop index
    links = links.str.split('&sa',1).reset_index().drop('index',1)
    # this is now a dataframe

    # use iterrows to grab first entry in each list which should be the working url
    links_cleaned = []
    for row in links.iterrows():
        links_cleaned.append(row[1][0][0])
        
    # convert to dataframe
    links_cleaned = DataFrame(links_cleaned)

    return links_cleaned[0]

# %%
burberry_links = search_google('burberry limited')

# %%
# use webbrowser library to open all links in browser (if needed)
for link in burberry_links:
    webbrowser.open(link)

# %% [markdown]
# ### Extract key text from company websites

# %% [markdown]
# Now that we've got the functionality to return links from Google search results, we want to navigate to each link, scrape and format the text to find words with explanatory value after removing stopwords and other standard website text. Let's use the Dyson website as an example.

# %%
dyson_links = search_google('Dyson Limited')

# %%
# Inspecting the first search result
# Read HTML
html = requests.get(dyson_links[0])
# Parse HTML into a BeautifulSoup object
soup = BeautifulSoup(html.content, 'html5lib')

# %%
# Extracting text from key html sections
[s.extract() for s in soup(['style', 'script', '[document]', 'head', 'title'])]

# %%
# Get all visible text
text = soup.getText().encode('ascii','ignore')

# %% [markdown]
# We want to clean up this text by removing HTML tags and new line indicators.

# %%
text_r = str(text).replace('\\n','').replace('\\t','').replace('\\r','')
print(text_r)

# %%
def stripsymbols(text):
    '''
    Use regular expressions to do a find-and-replace of HTML text.
    Function found online
    '''
    text = str(text)
    x = re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",text)
    x = re.sub('/(^|\b)@\S*($|\b)/'," ",x)
    x = re.sub('/(^|\b)#\S*($|\b)/'," ",x)
    x = re.sub("[^a-zA-Z]"," ",x)
    x = re.sub(r"(?:\@|https?\://)\S+", " ",x)
    return x

# %%
text_stripped = stripsymbols(text_r)
print(text_stripped)

# %% [markdown]
# Getting better! The final step is remove stop words by invoking the Natural Language Toolkit Library we imported earlier. Let's see what kind of stop words are classified in the library.

# %%
print(stopwords.words('English'))

# %% [markdown]
# We can create a function to remove stopwords from website text.

# %%
def removeStopWords(text):
    '''
    Remove stopwords from given text string
    '''
    words = [w for w in text if not w in stopwords.words("english")]
    return words

# %%
# Prepare text for function by (a) changing to lowercase (2) remove whitespace from beginning and end 
# (3) splitting the text to create a list of individual wordsvisible_text_stripped.lower().strip().split() 
text_stripped_split = text_stripped.lower().strip().split()
text_stripped_split

# %% [markdown]
# Finally, running this through the removeStopWords function gives us something in a much better shape than the original text.

# %%
text_cleaned = removeStopWords(text_stripped_split)
text_cleaned

# %% [markdown]
# Wrapping this all up into a function...

# %%
def cleantext(text):
    text_r = str(text).replace('\\n','').replace('\\t','').replace('\\r','')
    text_stripped = stripsymbols(text_r)
    text_stripped_split = text_stripped.lower().strip().split()
    text_cleaned = removeStopWords(text_stripped_split)
    return ' '.join(text_cleaned) # returns a joined list of the remaining words

# %%
dyson_cleaned = cleantext(text) # example of a function
dyson_cleaned

# %% [markdown]
# ### Using the Natural Language Toolkit to tokenise and tag words

# %% [markdown]
# Another feature of the Natural Language Toolkit we can exploit is the ability to tag words and categorise them into their 'parts of speech' (i.e. nouns, verbs, adverbs). Perhaps this can be used to tag words from the scraped text, and retrieve nouns under the assumption that they provide the greatest explanatory power.
#
# Let's test this with the scraped text from the previous section.

# %%
dyson_cleaned

# %%
tokens = nltk.word_tokenize(dyson_cleaned) # tokenize (split) the string
print(tokens)

# %% [markdown]
# The tags bellow are given according to the Penn Treebank Project here: https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html
#
# The results are quite interesting. Words like 'vacuums', 'cylinders', 'robot' and 'dryers' are correctly given as nouns. However, some words are double-tagged. For instance, 'dyson' is given as a verb as well as a noun. 'Airblade' is given as a past-tense verb.
#
# From this example alone, filtering on nouns would yield the best results.

# %%
tagged = nltk.pos_tag(tokens) # categorise words according to their parts of speech
print(tagged)

# %%
# Keep nouns only
tagged_nouns = " ".join([word[0] for word in tagged if word[1] in ['NNS','NN']])
tagged_nouns

# %%
# Difference in list sizes - 1,352 removed words (out of 3,767)
len(dyson_cleaned) - len(tagged_nouns)

# %% [markdown]
# ### Master function and wordclouds

# %% [markdown]
# Let's collect everything we've built in Section 2 and build our final master functions.

# %%
def key_words(list_of_urls):
    '''
    From the given list of urls, this function scrapes, cleans (removing symbols and non-nouns)
    and gathers all text into a single string
    '''
    
    words_cleaned = '' # Set up empty string
    
    for website in list_of_urls:
        # try / except for troublesome websites
        try:
            html = requests.get(website)
            soup = BeautifulSoup(html.content, 'html5lib')
            [s.extract() for s in soup(['style', 'script', '[document]', 'head', 'title'])]
            visibleText = soup.getText().encode('ascii','ignore')
            words_cleaned += cleantext(visibleText) # Calling the function we built earlier 
        except:
            continue
            
    # Tokenize and tag words
    tokens = nltk.word_tokenize(words_cleaned)
    tagged = nltk.pos_tag(tokens)

    # Keep nouns only
    keywords = " ".join([word[0] for word in tagged if word[1] in ['NNS','NN']])
    return keywords

# %%
key_words(search_google('Dyson Limited')) # testing on an example - takes a few seconds to run

# %% [markdown]
# This is best visualised in a word cloud...

# %%
def cloud(words):
    '''
    Function that takes in a string and produces a word cloud
    '''
    wordcloud = WordCloud(stopwords=STOPWORDS,
                          background_color='black',
                          width=1800,
                          height=1400
                         ).generate(words)

    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()
    return wordcloud

# %%
cloud(key_words(search_google('Royal Dutch Shell'))) # can take upto a minute to run

# %%
x = cloud(key_words(search_google('carillion')))

# %% [markdown]
# There is a lot of scope to improve this. Certain terms from websites that commonly re-occur can be filtered out by updating the stopwords set as follows.

# %%
# ways to improve this: list of common names, weights and quantities, months and dates,

custom_words = ['sun','new','showbiz','tv','uk','john','lewis','partnership','offers','store',
'business','company','stores','shop','department','partner','street','london','partners','peter',
'jones','duration', 'views', 'minutes', 'month', 'version', 'system','tesco','september','privacy',
'policy','customer','service','home', 'company', 'london', 'price', 'offer', 'customer',
'service', 'home', 'year', 'london', 'day', 'march', 'business', 'shop','item','level','logo','menu',
'account','co','road','centre']


#STOPWORDS is a set, so need to use update method
STOPWORDS.update(custom_words)

# %% [markdown]
# ## Connecting to Google Places API

# %% [markdown]
# We've relied on Google Search results to hopefully get websites that relate to a company term. However, the Google Places API can be linked to with a company's name and postcode and used to retrieve the company website and other details.
#
# Information from Google Places is displayed for certain businesses and places of interest as shown below.

# %% [markdown]
# ![title](Images/google_places_screenshot.png)

# %% [markdown]
# ### Modules and setup

# %% [markdown]
# We begin as usual by importing the required modules

# %%
import pandas as pd
import numpy as np
import requests
from time import sleep # to pause requests when web-scraping
import geopy.distance # to calculate distances
import re # regex to remove symbols

# %% [markdown]
# Google Places API requests can be called with the requests package. By default, you'll be able to send 1,000 requests per day but this can be increased free of charge, up to 150,000 requests per 24 hour period, by enabling billing on the Google API Console to verify your identity. Check quota here (after registering): http://code.google.com/apis/console

# %%
YOUR_API_KEY = '' # enter API key which you'll receive from Google

# %% [markdown]
# Check documentation here for info on the various Google Places APIs: https://developers.google.com/places/web-service/

# %% [markdown]
# Let's use the postcode for London Eye as an example: SE1 7PB. We'll need to input the longitude and latitude for this

# %%
postcode = 'SE1 7PB'

# %%
html = requests.get("http://api.postcodes.io/postcodes/" + postcode)
html.json()

# %%
lat = html.json()['result']['latitude']
lon = html.json()['result']['longitude']
lat, lon

# %% [markdown]
# ### Nearby search

# %% [markdown]
# A Nearby Search lets you search for places within a specified area. You can refine your search request by supplying keywords or specifying the type of place you are searching for. A nearby search request is an HTML URL of the following form:

# %% [markdown]
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-33.8670522,151.1957362&radius=500&type=restaurant&keyword=cruise&key=YOUR_API_KEY

# %% [markdown]
# Using the London Eye as an example:

# %%
london_eye = requests.get('https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=' + \
                          str(lat) + ',' + str(lon)  + '&' + 'keyword=London+Eye' + '&' + \
                          'rankby=distance' + '&' + \
                          'key=' + str(YOUR_API_KEY))
london_eye.json()

# %% [markdown]
# Exploring the json() file...

# %%
london_eye.json()['results'] # list of results

# %%
london_eye.json()['results'][0]['name'] # name of place

# %%
le_id = london_eye.json()['results'][0]['place_id'] # id of location 
le_id

# %% [markdown]
# Now that we've got the id, we can get the website from the text search API.

# %% [markdown]
# Before leaving this section, let's build a function that returns the location id from a given set of parameters. We'll need to call upon this function later.

# %%
def distance(lat1, lon1, lat2, lon2):
    '''
    Calculate distance (in km) between two sets of latitude and longitude coordinates
    Uses geopy package
    '''
    x = lat1, lon1
    y = lat2, lon2
    return geopy.distance.vincenty(x, y).km

# %%
def nearby_search(lat,lon,keyword,api_key):
    '''
    input: latitude and longitude (floats), api_key for Google Places (string)
    output: location_id of place closest to co-ordinates and that matches the keyword
    if the company is not found, then a message will be given
    '''
    
    # HTML wrapped for arguments
    html = requests.get('https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=' + \
                        str(lat) + ',' + str(lon)  + '&' + 'keyword=' + keyword + '&' + \
                        'rankby=distance' + '&' + 'key=' + str(api_key))
        
    # Error message if location not found
    try: 
        place_id = html.json()['results'][0]['place_id']
    except:
        return 'Location not found'
    
    # Check how close the search result is, reject if more than 1km distance
    
    # Coordinates from Google Places
    lat_g = html.json()['results'][0]['geometry']['location']['lat']
    lon_g = html.json()['results'][0]['geometry']['location']['lng']

    if distance(lat, lon, lat_g, lon_g) > 10: # more than 10km away
        return 'Location too far'
    
    # return html.json()
    return place_id

# %%
# testing the function
nearby_search(51.5028202620979,-0.119252376858172,'London Eye',YOUR_API_KEY) # correct

# %%
# Returns a KFC about 1 mile from the London Eye. Since we can't restrict radius with the rankby parameter, 
# depending on how strict the business name matching is, we run the risk of mismatches
nearby_search(51.5028202620979,-0.119252376858172,'KFC',YOUR_API_KEY)

# %%
nearby_search(51.5028202620979,-0.119252376858172,'London',YOUR_API_KEY) # returns 'London' - the entire city?

# %%
nearby_search(51.5028202620979,-0.119252376858172,'Eye',YOUR_API_KEY) # Specsavers in the Strand
# Out:
# 'ChIJDYZYNsoEdkgRHCQ30Uysy_M'

# %%
nearby_search(51.5028202620979,-0.119252376858172,'Wheel',YOUR_API_KEY) # Kwik-fit in Elephant & Castle

# %%
nearby_search(51.5028202620979,-0.119252376858172,'Ferris Wheel',YOUR_API_KEY) # Correct - London Eye
# Out:
# 'ChIJc2nSALkEdkgRkuoJJBfzkUI'

# %%
nearby_search(50.547036619931,-3.49639521511686,'R.B.W. DEVELOPMENTS LTD.',YOUR_API_KEY) # Testing sample

# %% [markdown]
# #### QA (reinforce postcode check)

# %% [markdown]
# With the London Eye example, the postcode which is input is 'SE1 7PB', which has corresponding coordinates of (51.5028202620979, -0.119252376858172). Google Nearby Search returns (51.503324, -0.119543) which is close enough.
#
# However, if any results are more than a certain distance away (say 1km), we reject them.

# %%
# Get coordinates from google places
lat_g = london_eye.json()['results'][0]['geometry']['location']['lat']

# %%
lon_g = london_eye.json()['results'][0]['geometry']['location']['lng']

# %%
lat, lon

# %%
lat_g, lon_g

# %%
def distance(lat1, lon1, lat2, lon2):
    '''
    Calculate distance (in km) between two sets of latitude and longitude coordinates
    Uses geopy package
    '''
    x = lat1, lon1
    y = lat2, lon2
    return geopy.distance.vincenty(x, y).km

# %%
distance(lat,lon,lat_g,lon_g)

# %% [markdown]
# ### Place search

# %% [markdown]
# Link here: https://developers.google.com/places/web-service/details

# %% [markdown]
# Once you have a place_id from a Place Search, you can request more details about a particular establishment or point of interest by initiating a Place Details request. A Place Details request returns more comprehensive information about the indicated place such as its complete address, phone number, user rating and reviews. A Place Details request is an HTTP URL of the following form:

# %%
https://maps.googleapis.com/maps/api/place/details/output?parameters

# %% [markdown]
# Calling this on the London Eye place id..

# %%
london_eye_website = requests.get('https://maps.googleapis.com/maps/api/place/details/json?' + \
                    'placeid=' + le_id + '&' + 'key=' + str(YOUR_API_KEY))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-b8016f643128> in <module>()
# ----> 1 london_eye_website = requests.get('https://maps.googleapis.com/maps/api/place/details/json?' +                     'placeid=' + le_id + '&' + 'key=' + str(YOUR_API_KEY))
#
# NameError: name 'le_id' is not defined

# %%
london_eye_website.json()['result'] # list of results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-750e4dac82e5> in <module>()
# ----> 1 london_eye_website.json()['result'] # list of results
#
# NameError: name 'london_eye_website' is not defined

# %%
london_eye_website.json()['result']['formatted_address']

# %%
london_eye_website.json()['result']['international_phone_number']

# %%
london_eye_website.json()['result']['opening_hours'] # dictionary of opening hours

# %%
london_eye_website.json()['result']['reviews'] # reviews

# %%
london_eye_website.json()['result']['reviews'] # example of a review - NLP potential

# %%
london_eye_website.json()['result']['website'] # place website

# %% [markdown]
# As before, let's build a helper function for convenience in the following section

# %%
def place_search(place_id):
    '''
    input: place_id from Nearby Search API (string)
    output: company website (if found)
    If a website is not found, then an error message will be given
    '''
    
    # exception in case place_id doesn't yield results in Place Search
    try:
        html = requests.get('https://maps.googleapis.com/maps/api/place/details/json?' + \
                    'placeid=' + place_id + '&' + 'key=' + str(YOUR_API_KEY))
    except:
        return 'No results in Place Search'
    
    # exception if website is not found
    try:
        website = html.json()['result']['website']
    except:
        return 'Website not found'
    
    return website

# %%
# Testing function with London Eye ID
place_search('ChIJc2nSALkEdkgRkuoJJBfzkUI')
# Out:
# 'http://www.londoneye.com/'

# %%
# Testing function with other IDs
place_search('ChIJmbKqQlgDdkgRfkx7-tWdNU4') # KFC in Lambeth - not branch-specific
# Out:
# 'http://www.kfc.co.uk/'

# %%
place_search('ChIJdd4hrwug2EcRmSrV3Vo6llI') # for London - website not avaiable

# %%
place_search('ChIJDYZYNsoEdkgRHCQ30Uysy_M') # Specsavers - branch-specific

# %%
place_search('ChIJWwBL554EdkgRluPLRtvCKek') # Kwik-fit - branch specific

# %% [markdown]
# ### Function to return website from given companies house details

# %% [markdown]
# Let's bring some of the pieces in the previous sections together to build a function that returns the company website (if found) from details found in the publicly-available Companies House dataset.

# %% [markdown]
# In Section 1.4, we exported a cleaned-up dataset of Companies House to a local directly. Let's import this now.

# %%
ch = pd.read_csv('ch_2018-02.csv')

# %%
ch.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-099ad5712657> in <module>()
# ----> 1 ch.shape
#
# NameError: name 'ch' is not defined

# %% [markdown]
# We'll be running the business name and the postcode through the Google Places API. The business name should be given but we'll need to exclude those records where the postcode is not given.

# %%
ch_pc = ch[ch.postcode.notnull()].copy()
ch_pc.shape
# Out:
# (4088872, 18)

# %% [markdown]
# Ok, so we've got our dataset. Let's now put our function together.

# %%
def return_website(company_name,postcode):
    '''
    Input: company name and postcode (both strings)
    Output: Company website
    '''
    
    # Step 1: Convert postcodes to latitude and longitude using postcodes.io
    # Some companies may give invalid postcodes in Companies House so build exception
    
    try: 
        html = requests.get("http://api.postcodes.io/postcodes/" + postcode)
        lat = html.json()['result']['latitude']
        lon = html.json()['result']['longitude']
    except:
        return 'Postcode not found'
    
    # Step 2: Get place_id by calling upon a Nearby Search (see Section 3.2)
    place_id = nearby_search(lat,lon,company_name,YOUR_API_KEY)
    
    # Step 3: Return website by feeding place_id into Place Search
    website = place_search(place_id)
    
    return website

# %% [markdown]
# ### Testing function on Companies House

# %% [markdown]
# Now for the fun stuff: let's test this function on a sample of companies in Companies House and see how many companies we get websites for.

# %%
# Random sample of a 100 companies from those entries with a postcode, only return name and postcode
ch_random_100 = ch_pc.sample(100)[['name','postcode']].copy()

# %%
ch_random_100.loc['website'] = np.NAN # set up blank column
ch_random_100
# Out:
#                                                       name  postcode  \
# 751960               CHANNEL FIVE TELEVISION GROUP LIMITED   EH7 5JA
# 3029580                         R.D. HAYLOCK & SON LIMITED  IP33 1NE
# 3264450                                        SCABIET LTD   NN4 7PA
# 1413995                          FOULDS SOLICITORS LIMITED  SG12 0EF
# 2458498                           MIDAS COMPONENTS LIMITED  NR31 0DU
# 2884993                  PIXEL COMPUTERS SOLUTIONS LIMITED  NP44 1HE
# 2932398                             PREDICTO.AI UK LIMITED   WD3 1JE
# 1229534                                        ELVIVIO LLP   E13 9PJ
# 1240114                   EMPTAGE WESTWOOD CONTRACTING LTD   M25 9NX
# 2026237                     K.T.E. LEGAL SOLUTIONS LIMITED   BR1 4AW
# 2923282                                    POWER EQUIP LTD  BH25 5NU
# 2938297                                    PREPMUM LIMITED  EC1V 2NX
# 3607358                                     TATARUSANU LTD   E13 8DZ
# 3306436                   SEU CARRELAGE NIZETTE INVEST LTD  CT16 1PW
# 3214204                                  S&R UTILITIES LTD   DY3 4PL
# 3149801           ROBERT QUINN ELECTRICAL SERVICES LIMITED   DE7 6BA
# 3742544                    THEATRE GLOUCESTERSHIRE LIMITED   GL1 1RP
# 3169260                    ROSCONN (HARDY EUSTACE) LIMITED   B90 2EL
# 2201360                                    LIFT-ADVICE LTD  WA14 1RR
# 2224909                           LIVE 4 ADVENTURE LIMITED  CA12 4EJ
# 3306623                       SEU YOURTRAININGSOLUTION LTD  CT17 0HL
# 3364723                                  SIPNSNACK LIMITED   TW9 2NA
# 3323435                                SHE SCAFFOLDING LTD  ME15 8NL
# 431492                                 BATH SPA GLOBAL LLP   BA2 9BN
# 349685                                         ATB LIMITED  CV21 1JX
# 2116023                                          KTS73 LTD   CR0 6LE
# 1462506                            G.D.SEARLE & CO.LIMITED  CT13 9NJ
# 848744                                   COGITAMUS LIMITED   PE3 6HD
# 2634398                                    NICOLIV 365 LTD  DA12 1EX
# 1251528                                      ENROLLING LTD   NN9 6DS
# ...                                                    ...       ...
# 1810541                         ILLUMIA AESTHETICS LIMITED   EN5 5UE
# 1412462               FORWARD THINKERS NORTHUMBRIA LIMITED  NE49 0PQ
# 1644453                                   HANDYBEAVERS LTD    E7 9AR
# 1946223                           JD FOOD AND WINE LIMITED   UB2 4EE
# 932962          CREIGHTON MEWS DEVELOPMENT COMPANY LIMITED   BT9 6GN
# 4085223                               WRAPPED IN STYLE LTD   G84 7QQ
# 1528364                                   GLITTERS LIMITED   WS9 8NL
# 2021172                     K LO BUSINESS SERVICES LIMITED  CV23 0GS
# 2366737                      MARLEY COMMUNICATIONS LIMITED   PL4 6HB
# 1115836                            DOUBLE R RACING LIMITED  GU21 5JY
# 922297          CRAG HEAD MANAGEMENT (BOURNEMOUTH) LIMITED  BH25 6QJ
# 3601483                          TANSTONE SERVICES LIMITED  YO26 8AS
# 1181692                        ECCLESHALL BUILDERS LIMITED  DE14 1PT
# 344260                ASSURED BOOKKEEPING SERVICES LIMITED  BN22 8SX
# 3772224  TIPTON & COSELEY BUILDING SOCIETY CHARITABLE F...   DY4 8HG
# 1800436                        IDE HILL COMMUNITY SHOP CIC  TN13 1LP
# 3317581                       SHANGHAI LAND (CITY) LIMITED  EC2V 7AY
# 736000       CENTRAL LONDON COLLEGE OF REFLEXOLOGY LIMITED  WC1X 8AZ
# 2394445                                   MAYFLIEZ LIMITED  WC1N 3AX
# 3598096                                TAMAS JURAK LIMITED   E14 9TS
# 999871                         DANIEL ALEXANDER DESIGN LTD  WC2H 9JQ
# 3569921             SWISSPORT FUELLING SERVICES UK LIMITED   WA7 1TT
# 415345                                  BANTU HOLDINGS LTD  WD24 4HS
# 905179                            CORVID SOLUTIONS LIMITED  SO19 8FF
# 3828487                            TRIDENTA ASSOCIATES LTD  NE11 0RU
# 2981193                                PSC PHOTOGRAPHY LTD   IG8 8EY
# 134959                                        ADAM INC LTD   OL4 1RS
# 1044516                              DELLO SPIRITO LIMITED   IG9 5RD
# 2694088                OAKWOOD VETERINARY PRACTICE LIMITED  RH12 3SH
# website                                                NaN       NaN
#
#                    website
# 751960   Website not found
# 3029580                NaN
# 3264450                NaN
# 1413995                NaN
# 2458498                NaN
# 2884993                NaN
# 2932398                NaN
# 1229534                NaN
# 1240114                NaN
# 2026237                NaN
# 2923282                NaN
# 2938297                NaN
# 3607358                NaN
# 3306436                NaN
# 3214204                NaN
# 3149801                NaN
# 3742544                NaN
# 3169260                NaN
# 2201360                NaN
# 2224909                NaN
# 3306623                NaN
# 3364723                NaN
# 3323435                NaN
# 431492                 NaN
# 349685                 NaN
# 2116023                NaN
# 1462506                NaN
# 848744                 NaN
# 2634398                NaN
# 1251528                NaN
# ...                    ...
# 1810541                NaN
# 1412462                NaN
# 1644453                NaN
# 1946223                NaN
# 932962                 NaN
# 4085223                NaN
# 1528364                NaN
# 2021172                NaN
# 2366737                NaN
# 1115836                NaN
# 922297                 NaN
# 3601483                NaN
# 1181692                NaN
# 344260                 NaN
# 3772224                NaN
# 1800436                NaN
# 3317581                NaN
# 736000                 NaN
# 2394445                NaN
# 3598096                NaN
# 999871                 NaN
# 3569921                NaN
# 415345                 NaN
# 905179                 NaN
# 3828487                NaN
# 2981193                NaN
# 134959                 NaN
# 1044516                NaN
# 2694088                NaN
# website                NaN
#
# [101 rows x 3 columns]

# %%
# Retrieve websites for each company with a for loop
i = 1
for index, row in ch_random_100.iterrows():
    ch_random_100.loc[index,'website'] = return_website(row[0],row[1])
    print(str(i) + ' - ' + str(row[0]) + ' - ' + str(row[1]) + ' - ' + str(row[2]))
    i += 1
    sleep(0.001)
# Out:
# 1 - CHANNEL FIVE TELEVISION GROUP LIMITED - EH7 5JA - Website not found
# 2 - R.D. HAYLOCK & SON LIMITED - IP33 1NE - Website not found
# 3 - SCABIET LTD - NN4 7PA - http://www.x-tremesystems.com/
# 4 - FOULDS SOLICITORS LIMITED - SG12 0EF - http://www.foulds.uk.com/
# 5 - MIDAS COMPONENTS LIMITED - NR31 0DU - http://midas-components.com/
# 6 - PIXEL COMPUTERS SOLUTIONS LIMITED - NP44 1HE - Website not found
# 7 - PREDICTO.AI UK LIMITED - WD3 1JE - Website not found
# 8 - ELVIVIO LLP - E13 9PJ - Website not found
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-397593754eea> in <module>()
#       2 i = 1
#       3 for index, row in ch_random_100.iterrows():
# ----> 4     ch_random_100.loc[index,'website'] = return_website(row[0],row[1])
#       5     print(str(i) + ' - ' + str(row[0]) + ' - ' + str(row[1]) + ' - ' + str(row[2]))
#       6     i += 1
#
# <ipython-input-32-3a338a1c944c> in return_website(company_name, postcode)
#      16
#      17     # Step 2: Get place_id by calling upon a Nearby Search (see Section 3.2)
# ---> 18     place_id = nearby_search(lat,lon,company_name,YOUR_API_KEY)
#      19
#      20     # Step 3: Return website by feeding place_id into Place Search
#
# <ipython-input-28-fe721f737551> in nearby_search(lat, lon, keyword, api_key)
#       7
#       8     # HTML wrapped for arguments
# ----> 9     html = requests.get('https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=' +                         str(lat) + ',' + str(lon)  + '&' + 'keyword=' + keyword + '&' +                         'rankby=distance' + '&' + 'key=' + str(api_key))
#      10
#      11     # Error message if location not found
#
# ~/Library/Python/3.6/lib/python/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~/Library/Python/3.6/lib/python/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~/Library/Python/3.6/lib/python/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~/Library/Python/3.6/lib/python/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~/Library/Python/3.6/lib/python/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1007                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1008                   self.__class__)
# -> 1009             return self.read(nbytes, buffer)
#    1010         else:
#    1011             return socket.recv_into(self, buffer, nbytes, flags)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in read(self, len, buffer)
#     869             raise ValueError("Read on closed or unwrapped SSL socket.")
#     870         try:
# --> 871             return self._sslobj.read(len, buffer)
#     872         except SSLError as x:
#     873             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
ch_random_100['website'].value_counts().head() # 17 websites out of 100

# %%
ch_random_100.to_csv('sample_of_100_websites.csv') # save results

# %% [markdown]
# Let's see if we can improve the match-rate by removing 'LTD. and 'LIMITED' from the end of the name

# %%
ch_random_100.loc[:,'website_2'] = np.NAN # set up blank column
ch_random_100

# %%
ch_random_100 = pd.read_csv('sample_of_100_websites.csv',index_col=0)

# %%
ch_random_100 = ch_random_100.head(100).copy()

# %%
def standardise(company_name):
    stopwords = ['limited','ltd','ltd.','lp']
    querywords = str(company_name).split()
    resultwords  = [word for word in querywords if word.lower() not in stopwords]
    result = ' '.join(resultwords)
    result_no_symbols = re.sub(r'[^\w]', '', result) # removes symbols
    return result_no_symbols.lower()

# %%
standardise('SHARP & SHINE INDUSTRIAL CO., LTD')
# Out:
# 'sharpshineindustrialco'

# %%
ch_random_100['name_stripped'] = ch_random_100['name'].apply(standardise)

# %%
ch_random_100 = pd.read_csv('datasets/sample_of_100_websites_2.csv', index_col = 0)

# %%
ch_random_100.head()

# %%
for index, row in ch_random_100.iterrows():
    print(row[0], row[1])

# %%
# Retrieve websites for each company with a for loop
i = 1
for index, row in ch_random_100.iterrows():
    ch_random_100.loc[index,'website_4'] = return_website(row[0],row[1])
    print(str(i) + ' - ' + str(row[0]) + ' - ' + str(row[1]) + ' - ' + str(row[6]))
    i += 1
    sleep(0.01)

# %%
ch_random_100['website_4'].value_counts() # 18 websites out of 100, lose some cases, gain others

# %%
ch_random_100.to_csv('sample_of_100_websites_3.csv') # save results

# %% [markdown]
# ### Testing on NYER LEP

# %% [markdown]
# Import postcode lookups for the North Yorkshire and East Riding LEP from the National Postcode Lookup Table

# %%
nyer_postcodes = pd.read_csv('nyer_postcode.csv')

# %%
nyer_postcodes.head() # three postcodes to lookup for

# %% [markdown]
# Let's do an inner join from the CH data to the NYER postcodes on the POSTCODE_PCDS column.

# %%
ch_nyer = pd.merge(ch_pc, nyer_postcodes, how='inner', left_on='postcode', right_on='POSTCODE_PCDS')

# %%
ch_nyer.shape # 12,486 companies. Similiar to what we're seeing in CSAT.

# %%
ch_nyer.loc[:,'website'] = np.NAN # set up blank column
ch_nyer

# %%
ch_nyer_1000 = ch_nyer.loc[:999,].copy()

# %%
ch_nyer_1000
# Out:
#                                                   name       crn  \
# 0                         "STREONSHALH" WHITBY LIMITED  01636551
# 1                               'OUT OF THIS WOLD' LTD  10553612
# 2                                        CLIFF TOP LTD  04623454
# 3                                     01722212 LIMITED  01722212
# 4                     WORLD WIDE SHOPPING MALL LIMITED  03307834
# 5                                         01AA LIMITED  10017240
# 6                                     1 VOYAGE LIMITED  04683525
# 7         INSITE TRAINING & RESPONSE SOLUTIONS LIMITED  09132004
# 8    1-4 MUSEUM TERRACE (SCARBOROUGH) MANAGEMENT CO...  06759604
# 9       15 ABERDEEN STREET FREEHOLD MANAGEMENT LIMITED  06629449
# 10           15 ALMA SQUARE MANAGEMENT COMPANY LIMITED  09739862
# 11                             156 CASTLE ROAD LIMITED  04099319
# 12                 2 ALMA COURT MANAGEMENT CO. LIMITED  03198835
# 13                         272 EARLSFIELD ROAD LIMITED  03921273
# 14           31 AND 33 VESPER ROAD RTM COMPANY LIMITED  07739726
# 15                             35 TRAFALGAR SQUARE LTD  06623041
# 16               6 BLENHEIM TERRACE MANAGEMENT LIMITED  06074579
# 17          A & D MOTOR SERVICES (SCARBOROUGH) LIMITED  09104365
# 18                   A.J. STREFFORD (BEVERLEY) LIMITED  02893895
# 19                A.J. STREFFORD (SCARBOROUGH) LIMITED  02893898
# 20                               ABSOLUTE ZERO LIMITED  09289954
# 21         ALEXANDER COURT FLATS MANAGEMENT CO LIMITED  02751436
# 22              ALNE MEWS (MANAGEMENT COMPANY) LIMITED  03639063
# 23                   ANDREW COWEN ESTATE AGENT LIMITED  03696005
# 24                           ARRAS RESTAURANTS LIMITED  10272677
# 25            ATTENBOROUGH HOTEL (SCARBOROUGH) LIMITED  00402282
# 26                              AUTO 66 RACING LIMITED  00980520
# 27                          AUTONOMOUS SYSTEMS LIMITED  06133968
# 28       AYCKBOURN CHAPTERS MANAGEMENT COMPANY LIMITED  02534371
# 29                         BASROS DEVELOPMENTS LIMITED  10800902
# ..                                                 ...       ...
# 970    CONSTRUCTION & BUILDING SERVICES (1994) LIMITED  02936207
# 971                                CROWN SURFACING LTD  10996129
# 972                         CUSTOMCALL SCARBOROUGH LTD  04445651
# 973                          DANE DEVELOPMENTS LIMITED  05125327
# 974                                DAWSON WAKE LIMITED  06553541
# 975                     DAWSON WAKE PROPERTIES LIMITED  08576038
# 976                                      GAMEQUEST LTD  10865161
# 977                          GATEWAYS DEVELOPMENTS LTD  10385763
# 978                              GEM (SCARBOROUGH) LTD  08542246
# 979                                 HAWKINS & WOLF LTD  08458180
# 980                         IDENTITY YORKSHIRE LIMITED  04745926
# 981                              INDIE APPAREL LIMITED  05265639
# 982                                 INDIE ICON LIMITED  06790996
# 983                 K.C. PRECISION ENGINEERING LIMITED  02831757
# 984  NORTH CLIFFE HEIGHTS MANAGEMENT COMPANY (NO.1)...  03033745
# 985                  P.W.A. MANAGEMENT COMPANY LIMITED  02731884
# 986                           PATCHWORK ENERGY LIMITED  07921738
# 987                             PEL (HOLDINGS) LIMITED  10493339
# 988                               PWE HEAT & POWER LTD  10773294
# 989                                RAYNER & CO LIMITED  07804122
# 990                          ROUTEONE PRODUCTS LIMITED  05754826
# 991          SCARBOROUGH & DISTRICT MOTOR CLUB LIMITED  00435947
# 992                  SCARBOROUGH BOOK FESTIVAL LIMITED  08900320
# 993                         SCARBOROUGH DECORATORS LTD  07671525
# 994                                      SINCO LIMITED  04447256
# 995                THE MOORINGS MANAGEMENT (FILEY) LTD  08351972
# 996             W.U. BUTTERFIELD (CARAVANNING) LIMITED  01322191
# 997                           YORKSHIRE COAST GIGS CIC  08971503
# 998     16 HIGH STREET PROPERTY MANAGEMENT COMPANY LTD  10534743
# 999                 COOKS AND KITCHENS KITCHENWARE LTD  04360268
#
#                                             address1  \
# 0                                      "STREONSHALH"
# 1                               MILLHOLME FARM HOUSE
# 2                      MILLHOLME FARM HOUSE, SPEETON
# 3                                    HILL VIEW HOUSE
# 4                                    HILL VIEW HOUSE
# 5    THE ROYAL HUNTING LODGE SHIPTON BY BENINGBROUGH
# 6                                   6 FEVERSHAM ROAD
# 7                                   6 FEVERSHAM ROAD
# 8                                  62-63 WESTBOROUGH
# 9                                62 - 63 WESTBOROUGH
# 10                                 62/63 WESTBOROUGH
# 11                                 62-63 WESTBOROUGH
# 12                                 62-63 WESTBOROUGH
# 13                                 62-63 WESTBOROUGH
# 14                                 62-63 WESTBOROUGH
# 15                                         WINN & CO
# 16                                 62/63 WESTBOROUGH
# 17                                 62/63 WESTBOROUGH
# 18                                       WINN AND CO
# 19                                       WINN AND CO
# 20                                 62/63 WESTBOROUGH
# 21                                 62-63 WESTBOROUGH
# 22                                 62/63 WESTBOROUGH
# 23                                 62/63 WESTBOROUGH
# 24                                 62/63 WESTBOROUGH
# 25                                 62/63 WESTBOROUGH
# 26                                 62/63 WESTBOROUGH
# 27                                 62/63 WESTBOROUGH
# 28                                 62-63 WESTBOROUGH
# 29                                 62/63 WESTBOROUGH
# ..                                               ...
# 970                                  6 ARUNDEL PLACE
# 971                                  6 ARUNDEL PLACE
# 972                                  6 ARUNDEL PLACE
# 973                                  6 ARUNDEL PLACE
# 974                                  6 ARUNDEL PLACE
# 975                                  6 ARUNDEL PLACE
# 976                                  RAYNER & CO LTD
# 977                                   6, RAYNER & CO
# 978                                      RAYNER & CO
# 979                                  6 ARUNDEL PLACE
# 980                                  6 ARUNDEL PLACE
# 981                                  6 ARUNDEL PLACE
# 982                                  6 ARUNDEL PLACE
# 983                                  6 ARUNDEL PLACE
# 984                                  6 ARUNDEL PLACE
# 985                                  6 ARUNDEL PLACE
# 986                                  6 ARUNDEL PLACE
# 987                                  6 ARUNDEL PLACE
# 988                                  6 ARUNDEL PLACE
# 989                                  6 ARUNDEL PLACE
# 990                                  6 ARUNDEL PLACE
# 991                                  C/O RAYNER & CO
# 992                                  6 ARUNDEL PLACE
# 993                                  6 ARUNDEL PLACE
# 994                                  6 ARUNDEL PLACE
# 995                                  6 ARUNDEL PLACE
# 996                                  6 ARUNDEL PLACE
# 997                                  6 ARUNDEL PLACE
# 998                                   16 HIGH STREET
# 999                                  OLDBRIDGE HOUSE
#
#                              address2           postTown           county  \
# 0                         KHYBER PASS             WHITBY  NORTH YORKSHIRE
# 1                      SPEETON STREET              FILEY              NaN
# 2                               FILEY          YORKSHIRE              NaN
# 3    CORNBOROUGH ROAD, SHERIFF HUTTON               YORK  NORTH YORKSHIRE
# 4    CORNBOROUGH ROAD, SHERIFF HUTTON               YORK  NORTH YORKSHIRE
# 5             SHIPTON BY BENINGBROUGH               YORK      NORTH YORKS
# 6                                 NaN           HELMSLEY  NORTH YORKSHIRE
# 7                                 NaN           HELMSLEY  NORTH YORKSHIRE
# 8                                 NaN        SCARBOROUGH  NORTH YORKSHIRE
# 9                                 NaN        SCARBOROUGH  NORTH YORKSHIRE
# 10                                NaN        SCARBOROUGH          N YORKS
# 11                        SCARBOROUGH    NORTH YORKSHIRE              NaN
# 12                        SCARBOROUGH    NORTH YORKSHIRE              NaN
# 13                        SCARBOROUGH    NORTH YORKSHIRE              NaN
# 14                                NaN        SCARBOROUGH  NORTH YORKSHIRE
# 15                  62/63 WESTBOROUGH        SCARBOROUGH  NORTH YORKSHIRE
# 16                        SCARBOROUGH                NaN              NaN
# 17                                NaN        SCARBOROUGH              NaN
# 18                  62-63 WESTBOROUGH        SCARBOROUGH  NORTH YORKSHIRE
# 19                  62-63 WESTBOROUGH        SCARBOROUGH  NORTH YORKSHIRE
# 20                                NaN        SCARBOROUGH              NaN
# 21                        SCARBOROUGH    NORTH YORKSHIRE              NaN
# 22                                NaN        SCARBOROUGH  NORTH YORKSHIRE
# 23                        SCARBOROUGH    NORTH YORKSHIRE              NaN
# 24                                NaN        SCARBOROUGH          N YORKS
# 25                        SCARBOROUGH    NORTH YORKSHIRE              NaN
# 26                        SCARBOROUGH    NORTH YORKSHIRE              NaN
# 27                        SCARBOROUGH                NaN              NaN
# 28                        SCARBOROUGH    NORTH YORKSHIRE              NaN
# 29                                NaN        SCARBOROUGH  NORTH YORKSHIRE
# ..                                ...                ...              ...
# 970                               NaN        SCARBOROUGH  NORTH YORKSHIRE
# 971                               NaN        SCARBOROUGH              NaN
# 972                       SCARBOROUGH    NORTH YORKSHIRE              NaN
# 973                               NaN        SCARBOROUGH  NORTH YORKSHIRE
# 974                               NaN        SCARBOROUGH  NORTH YORKSHIRE
# 975                               NaN        SCARBOROUGH  NORTH YORKSHIRE
# 976                   6 ARUNDEL PLACE        SCARBOROUGH              NaN
# 977                     ARUNDEL PLACE        SCARBOROUGH              NaN
# 978                   6 ARUNDEL PLACE        SCARBOROUGH              NaN
# 979                               NaN        SCARBOROUGH  NORTH YORKSHIRE
# 980                       SCARBOROUGH    NORTH YORKSHIRE              NaN
# 981                               NaN        SCARBOROUGH  NORTH YORKSHIRE
# 982                               NaN        SCARBOROUGH  NORTH YORKSHIRE
# 983                       SCARBOROUGH       N.YORKSHIRE,              NaN
# 984                       SCARBOROUGH    NORTH YORKSHIRE              NaN
# 985                       SCARBOROUGH    NORTH YORKSHIRE              NaN
# 986                               NaN        SCARBOROUGH  NORTH YORKSHIRE
# 987                               NaN        SCARBOROUGH  NORTH YORKSHIRE
# 988                               NaN        SCARBOROUGH  NORTH YORKSHIRE
# 989                               NaN        SCARBOROUGH  NORTH YORKSHIRE
# 990                               NaN        SCARBOROUGH  NORTH YORKSHIRE
# 991                   6 ARUNDEL PLACE        SCARBOROUGH  NORTH YORKSHIRE
# 992                               NaN        SCARBOROUGH  NORTH YORKSHIRE
# 993                               NaN        SCARBOROUGH  NORTH YORKSHIRE
# 994                       SCARBOROUGH    NORTH YORKSHIRE              NaN
# 995                               NaN        SCARBOROUGH  NORTH YORKSHIRE
# 996                       SCARBOROUGH    NORTH YORKSHIRE              NaN
# 997                               NaN        SCARBOROUGH  NORTH YORKSHIRE
# 998                         CATTERICK           RICHMOND              NaN
# 999                       HIGH STREET  CATTERICK VILLAGE  NORTH YORKSHIRE
#
#             country  postcode  \
# 0               NaN  YO21 3DQ
# 1    UNITED KINGDOM  YO14 9TG
# 2               NaN  YO14 9TG
# 3               NaN  YO60 6QJ
# 4               NaN  YO60 6QJ
# 5    UNITED KINGDOM  YO30 1BD
# 6               NaN  YO62 5HN
# 7               NaN  YO62 5HN
# 8               NaN  YO11 1TS
# 9               NaN  YO11 1TS
# 10   UNITED KINGDOM  YO11 1TS
# 11              NaN  YO11 1TS
# 12              NaN  YO11 1TS
# 13              NaN  YO11 1TS
# 14              NaN  YO11 1TS
# 15              NaN  YO11 1TS
# 16              NaN  YO11 1TS
# 17              NaN  YO11 1TS
# 18              NaN  YO11 1TS
# 19              NaN  YO11 1TS
# 20              NaN  YO11 1TS
# 21              NaN  YO11 1TS
# 22              NaN  YO11 1TS
# 23              NaN  YO11 1TS
# 24   UNITED KINGDOM  YO11 1TS
# 25              NaN  YO11 1TS
# 26              NaN  YO11 1TS
# 27              NaN  YO11 1TS
# 28              NaN  YO11 1TS
# 29   UNITED KINGDOM  YO11 1TS
# ..              ...       ...
# 970             NaN  YO11 1TX
# 971  UNITED KINGDOM  YO11 1TX
# 972             NaN  YO11 1TX
# 973             NaN  YO11 1TX
# 974             NaN  YO11 1TX
# 975             NaN  YO11 1TX
# 976  UNITED KINGDOM  YO11 1TX
# 977  UNITED KINGDOM  YO11 1TX
# 978         ENGLAND  YO11 1TX
# 979             NaN  YO11 1TX
# 980             NaN  YO11 1TX
# 981             NaN  YO11 1TX
# 982         ENGLAND  YO11 1TX
# 983             NaN  YO11 1TX
# 984             NaN  YO11 1TX
# 985             NaN  YO11 1TX
# 986         ENGLAND  YO11 1TX
# 987         ENGLAND  YO11 1TX
# 988         ENGLAND  YO11 1TX
# 989             NaN  YO11 1TX
# 990         ENGLAND  YO11 1TX
# 991             NaN  YO11 1TX
# 992         ENGLAND  YO11 1TX
# 993             NaN  YO11 1TX
# 994             NaN  YO11 1TX
# 995             NaN  YO11 1TX
# 996             NaN  YO11 1TX
# 997             NaN  YO11 1TX
# 998  UNITED KINGDOM  DL10 7LJ
# 999         ENGLAND  DL10 7LJ
#
#                                               category  \
# 0    PRI/LTD BY GUAR/NSC (Private, limited by guara...
# 1                              Private Limited Company
# 2                              Private Limited Company
# 3                              Private Limited Company
# 4                              Private Limited Company
# 5                              Private Limited Company
# 6                              Private Limited Company
# 7                              Private Limited Company
# 8                              Private Limited Company
# 9                              Private Limited Company
# 10                             Private Limited Company
# 11                             Private Limited Company
# 12                             Private Limited Company
# 13                             Private Limited Company
# 14   PRI/LTD BY GUAR/NSC (Private, limited by guara...
# 15                             Private Limited Company
# 16                             Private Limited Company
# 17                             Private Limited Company
# 18                             Private Limited Company
# 19                             Private Limited Company
# 20                             Private Limited Company
# 21                             Private Limited Company
# 22                             Private Limited Company
# 23                             Private Limited Company
# 24                             Private Limited Company
# 25                             Private Limited Company
# 26                             Private Limited Company
# 27                             Private Limited Company
# 28                             Private Limited Company
# 29                             Private Limited Company
# ..                                                 ...
# 970                            Private Limited Company
# 971                            Private Limited Company
# 972                            Private Limited Company
# 973                            Private Limited Company
# 974                            Private Limited Company
# 975                            Private Limited Company
# 976                            Private Limited Company
# 977                            Private Limited Company
# 978                            Private Limited Company
# 979                            Private Limited Company
# 980                            Private Limited Company
# 981                            Private Limited Company
# 982                            Private Limited Company
# 983                            Private Limited Company
# 984                            Private Limited Company
# 985                            Private Limited Company
# 986                            Private Limited Company
# 987                            Private Limited Company
# 988                            Private Limited Company
# 989                            Private Limited Company
# 990                            Private Limited Company
# 991  PRI/LTD BY GUAR/NSC (Private, limited by guara...
# 992  PRI/LTD BY GUAR/NSC (Private, limited by guara...
# 993                            Private Limited Company
# 994                            Private Limited Company
# 995                            Private Limited Company
# 996                            Private Limited Company
# 997                         Community Interest Company
# 998                            Private Limited Company
# 999                            Private Limited Company
#
#                               status  \
# 0                             Active
# 1                             Active
# 2                             Active
# 3                             Active
# 4                             Active
# 5                             Active
# 6                             Active
# 7                             Active
# 8                             Active
# 9                             Active
# 10                            Active
# 11                            Active
# 12                            Active
# 13                            Active
# 14                            Active
# 15                            Active
# 16                            Active
# 17                            Active
# 18                            Active
# 19                            Active
# 20                            Active
# 21                            Active
# 22                            Active
# 23                            Active
# 24                            Active
# 25                            Active
# 26                            Active
# 27                            Active
# 28                            Active
# 29                            Active
# ..                               ...
# 970                           Active
# 971                           Active
# 972                           Active
# 973                           Active
# 974                           Active
# 975                           Active
# 976                           Active
# 977                           Active
# 978                           Active
# 979                           Active
# 980                           Active
# 981                           Active
# 982                           Active
# 983                           Active
# 984                           Active
# 985                           Active
# 986                           Active
# 987                           Active
# 988                           Active
# 989                           Active
# 990  Active - Proposal to Strike off
# 991                           Active
# 992                           Active
# 993                           Active
# 994                           Active
# 995                           Active
# 996                           Active
# 997                           Active
# 998                           Active
# 999                           Active
#
#                            ...                         POSTCODE_PCDS  \
# 0                          ...                              YO21 3DQ
# 1                          ...                              YO14 9TG
# 2                          ...                              YO14 9TG
# 3                          ...                              YO60 6QJ
# 4                          ...                              YO60 6QJ
# 5                          ...                              YO30 1BD
# 6                          ...                              YO62 5HN
# 7                          ...                              YO62 5HN
# 8                          ...                              YO11 1TS
# 9                          ...                              YO11 1TS
# 10                         ...                              YO11 1TS
# 11                         ...                              YO11 1TS
# 12                         ...                              YO11 1TS
# 13                         ...                              YO11 1TS
# 14                         ...                              YO11 1TS
# 15                         ...                              YO11 1TS
# 16                         ...                              YO11 1TS
# 17                         ...                              YO11 1TS
# 18                         ...                              YO11 1TS
# 19                         ...                              YO11 1TS
# 20                         ...                              YO11 1TS
# 21                         ...                              YO11 1TS
# 22                         ...                              YO11 1TS
# 23                         ...                              YO11 1TS
# 24                         ...                              YO11 1TS
# 25                         ...                              YO11 1TS
# 26                         ...                              YO11 1TS
# 27                         ...                              YO11 1TS
# 28                         ...                              YO11 1TS
# 29                         ...                              YO11 1TS
# ..                         ...                                   ...
# 970                        ...                              YO11 1TX
# 971                        ...                              YO11 1TX
# 972                        ...                              YO11 1TX
# 973                        ...                              YO11 1TX
# 974                        ...                              YO11 1TX
# 975                        ...                              YO11 1TX
# 976                        ...                              YO11 1TX
# 977                        ...                              YO11 1TX
# 978                        ...                              YO11 1TX
# 979                        ...                              YO11 1TX
# 980                        ...                              YO11 1TX
# 981                        ...                              YO11 1TX
# 982                        ...                              YO11 1TX
# 983                        ...                              YO11 1TX
# 984                        ...                              YO11 1TX
# 985                        ...                              YO11 1TX
# 986                        ...                              YO11 1TX
# 987                        ...                              YO11 1TX
# 988                        ...                              YO11 1TX
# 989                        ...                              YO11 1TX
# 990                        ...                              YO11 1TX
# 991                        ...                              YO11 1TX
# 992                        ...                              YO11 1TX
# 993                        ...                              YO11 1TX
# 994                        ...                              YO11 1TX
# 995                        ...                              YO11 1TX
# 996                        ...                              YO11 1TX
# 997                        ...                              YO11 1TX
# 998                        ...                              DL10 7LJ
# 999                        ...                              DL10 7LJ
#
#            LAT      LONG       LEP1 LEP2 COUNTY_CODE COUNTY_DIST_CODE  \
# 0    54.488915 -0.615535  E37000039  NaN   E10000023        E07000168
# 1    54.155893 -0.239788  E37000039  NaN   E10000023        E07000168
# 2    54.155893 -0.239788  E37000039  NaN   E10000023        E07000168
# 3    54.091054 -1.009659  E37000039  NaN   E10000023        E07000167
# 4    54.091054 -1.009659  E37000039  NaN   E10000023        E07000167
# 5    54.051810 -1.166750  E37000039  NaN   E10000023        E07000164
# 6    54.250017 -1.058227  E37000039  NaN   E10000023        E07000167
# 7    54.250017 -1.058227  E37000039  NaN   E10000023        E07000167
# 8    54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 9    54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 10   54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 11   54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 12   54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 13   54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 14   54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 15   54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 16   54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 17   54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 18   54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 19   54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 20   54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 21   54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 22   54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 23   54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 24   54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 25   54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 26   54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 27   54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 28   54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 29   54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# ..         ...       ...        ...  ...         ...              ...
# 970  54.278287 -0.408249  E37000039  NaN   E10000023        E07000168
# 971  54.278287 -0.408249  E37000039  NaN   E10000023        E07000168
# 972  54.278287 -0.408249  E37000039  NaN   E10000023        E07000168
# 973  54.278287 -0.408249  E37000039  NaN   E10000023        E07000168
# 974  54.278287 -0.408249  E37000039  NaN   E10000023        E07000168
# 975  54.278287 -0.408249  E37000039  NaN   E10000023        E07000168
# 976  54.278287 -0.408249  E37000039  NaN   E10000023        E07000168
# 977  54.278287 -0.408249  E37000039  NaN   E10000023        E07000168
# 978  54.278287 -0.408249  E37000039  NaN   E10000023        E07000168
# 979  54.278287 -0.408249  E37000039  NaN   E10000023        E07000168
# 980  54.278287 -0.408249  E37000039  NaN   E10000023        E07000168
# 981  54.278287 -0.408249  E37000039  NaN   E10000023        E07000168
# 982  54.278287 -0.408249  E37000039  NaN   E10000023        E07000168
# 983  54.278287 -0.408249  E37000039  NaN   E10000023        E07000168
# 984  54.278287 -0.408249  E37000039  NaN   E10000023        E07000168
# 985  54.278287 -0.408249  E37000039  NaN   E10000023        E07000168
# 986  54.278287 -0.408249  E37000039  NaN   E10000023        E07000168
# 987  54.278287 -0.408249  E37000039  NaN   E10000023        E07000168
# 988  54.278287 -0.408249  E37000039  NaN   E10000023        E07000168
# 989  54.278287 -0.408249  E37000039  NaN   E10000023        E07000168
# 990  54.278287 -0.408249  E37000039  NaN   E10000023        E07000168
# 991  54.278287 -0.408249  E37000039  NaN   E10000023        E07000168
# 992  54.278287 -0.408249  E37000039  NaN   E10000023        E07000168
# 993  54.278287 -0.408249  E37000039  NaN   E10000023        E07000168
# 994  54.278287 -0.408249  E37000039  NaN   E10000023        E07000168
# 995  54.278287 -0.408249  E37000039  NaN   E10000023        E07000168
# 996  54.278287 -0.408249  E37000039  NaN   E10000023        E07000168
# 997  54.278287 -0.408249  E37000039  NaN   E10000023        E07000168
# 998  54.376944 -1.630218  E37000039  NaN   E10000023        E07000166
# 999  54.376944 -1.630218  E37000039  NaN   E10000023        E07000166
#
#      WARD_CODE                                  website  \
# 0    E05006340            http://www.streonshalh.co.uk/
# 1    E05006327                        Website not found
# 2    E05006327                        Website not found
# 3    E05006313                        Website not found
# 4    E05006313  http://www.worldwideshoppingmall.co.uk/
# 5    E05009677                        Website not found
# 6    E05006302               http://www.voyagecare.com/
# 7    E05006302                        Website not found
# 8    E05006317                        Website not found
# 9    E05006317                        Website not found
# 10   E05006317                        Website not found
# 11   E05006317                        Website not found
# 12   E05006317                        Website not found
# 13   E05006317                        Website not found
# 14   E05006317                        Website not found
# 15   E05006317                        Website not found
# 16   E05006317                        Website not found
# 17   E05006317     http://www.scarboroughdialaride.org/
# 18   E05006317                        Website not found
# 19   E05006317                        Website not found
# 20   E05006317                        Website not found
# 21   E05006317                        Website not found
# 22   E05006317                        Website not found
# 23   E05006317              http://www.andrewcowen.com/
# 24   E05006317                        Website not found
# 25   E05006317                        Website not found
# 26   E05006317       http://www.oliversmountracing.com/
# 27   E05006317                        Website not found
# 28   E05006317                        Website not found
# 29   E05006317                        Website not found
# ..         ...                                      ...
# 970  E05006317                        Website not found
# 971  E05006317                        Website not found
# 972  E05006317             http://www.customcall.co.uk/
# 973  E05006317                        Website not found
# 974  E05006317                        Website not found
# 975  E05006317                        Website not found
# 976  E05006317                        Website not found
# 977  E05006317                        Website not found
# 978  E05006317                        Website not found
# 979  E05006317                        Website not found
# 980  E05006317               http://www.identity.co.uk/
# 981  E05006317                        Website not found
# 982  E05006317                        Website not found
# 983  E05006317         http://www.kc-engineering.co.uk/
# 984  E05006317                        Website not found
# 985  E05006317                        Website not found
# 986  E05006317          http://www.patchworkenergy.com/
# 987  E05006317                        Website not found
# 988  E05006317                        Website not found
# 989  E05006317            http://www.raynerandco.co.uk/
# 990  E05006317                        Website not found
# 991  E05006317                        Website not found
# 992  E05006317                        Website not found
# 993  E05006317                        Website not found
# 994  E05006317                  http://www.sinco.co.uk/
# 995  E05006317                        Website not found
# 996  E05006317                        Website not found
# 997  E05006317                        Website not found
# 998  E05006277                        Website not found
# 999  E05006277                        Website not found
#
#                                           social_media
# 0                                                set()
# 1                                            Not found
# 2                                            Not found
# 3                                            Not found
# 4    {'https://plus.google.com/110394507306641485115'}
# 5                                            Not found
# 6    {'https://twitter.com/voyagecare', 'https://ww...
# 7                                            Not found
# 8                                            Not found
# 9                                            Not found
# 10                                           Not found
# 11                                           Not found
# 12                                           Not found
# 13                                           Not found
# 14                                           Not found
# 15                                           Not found
# 16                                           Not found
# 17           {'http://www.twitter.com/tweetdialaride'}
# 18                                           Not found
# 19                                           Not found
# 20                                           Not found
# 21                                           Not found
# 22                                           Not found
# 23                                               set()
# 24                                           Not found
# 25                                           Not found
# 26   {'https://twitter.com/auto66racing', 'https://...
# 27                                           Not found
# 28                                           Not found
# 29                                           Not found
# ..                                                 ...
# 970                                          Not found
# 971                                          Not found
# 972                                              set()
# 973                                          Not found
# 974                                          Not found
# 975                                          Not found
# 976                                          Not found
# 977                                          Not found
# 978                                          Not found
# 979                                          Not found
# 980  {'https://twitter.com/IdentityMuston', 'https:...
# 981                                          Not found
# 982                                          Not found
# 983                                              set()
# 984                                          Not found
# 985                                          Not found
# 986                                              set()
# 987                                          Not found
# 988                                          Not found
# 989                                              set()
# 990                                          Not found
# 991                                          Not found
# 992                                          Not found
# 993                                          Not found
# 994                                              set()
# 995                                          Not found
# 996                                          Not found
# 997                                          Not found
# 998                                          Not found
# 999                                          Not found
#
# [1000 rows x 30 columns]

# %%
# Retrieve websites for each company with a for loop
for index, row in ch_nyer_1000.iterrows():
    if pd.notnull(row[28]) == True:
        continue
    ch_nyer_1000.loc[index,'website'] = return_website(row[0],row[7]) 
    print(str(index) + ' - ' + str(row[0]) + ' - ' + str(row[7]) + ' - ' + str(ch_nyer_1000.loc[index,'website']))
    sleep(0.001)

# %%
ch_nyer_1000['website'].value_counts() # 3,176 websites found for 12,486 (25%), some of these are duplicates

# %%
ch_nyer_1000.to_csv('nyer_with_websites.csv')

# %% [markdown]
# #### Test with improved accuracy (26/03)

# %%
# import previous dataset that contained websites and social media accounts using old method
ch_nyer = pd.read_csv('datasets/nyer_with_websites_sm.csv', index_col = 0)

# %%
ch_nyer.head(30)
# Out:
#                                                  name       crn  \
# 0                        "STREONSHALH" WHITBY LIMITED  01636551
# 1                              'OUT OF THIS WOLD' LTD  10553612
# 2                                       CLIFF TOP LTD  04623454
# 3                                    01722212 LIMITED  01722212
# 4                    WORLD WIDE SHOPPING MALL LIMITED  03307834
# 5                                        01AA LIMITED  10017240
# 6                                    1 VOYAGE LIMITED  04683525
# 7        INSITE TRAINING & RESPONSE SOLUTIONS LIMITED  09132004
# 8   1-4 MUSEUM TERRACE (SCARBOROUGH) MANAGEMENT CO...  06759604
# 9      15 ABERDEEN STREET FREEHOLD MANAGEMENT LIMITED  06629449
# 10          15 ALMA SQUARE MANAGEMENT COMPANY LIMITED  09739862
# 11                            156 CASTLE ROAD LIMITED  04099319
# 12                2 ALMA COURT MANAGEMENT CO. LIMITED  03198835
# 13                        272 EARLSFIELD ROAD LIMITED  03921273
# 14          31 AND 33 VESPER ROAD RTM COMPANY LIMITED  07739726
# 15                            35 TRAFALGAR SQUARE LTD  06623041
# 16              6 BLENHEIM TERRACE MANAGEMENT LIMITED  06074579
# 17         A & D MOTOR SERVICES (SCARBOROUGH) LIMITED  09104365
# 18                  A.J. STREFFORD (BEVERLEY) LIMITED  02893895
# 19               A.J. STREFFORD (SCARBOROUGH) LIMITED  02893898
# 20                              ABSOLUTE ZERO LIMITED  09289954
# 21        ALEXANDER COURT FLATS MANAGEMENT CO LIMITED  02751436
# 22             ALNE MEWS (MANAGEMENT COMPANY) LIMITED  03639063
# 23                  ANDREW COWEN ESTATE AGENT LIMITED  03696005
# 24                          ARRAS RESTAURANTS LIMITED  10272677
# 25           ATTENBOROUGH HOTEL (SCARBOROUGH) LIMITED  00402282
# 26                             AUTO 66 RACING LIMITED  00980520
# 27                         AUTONOMOUS SYSTEMS LIMITED  06133968
# 28      AYCKBOURN CHAPTERS MANAGEMENT COMPANY LIMITED  02534371
# 29                        BASROS DEVELOPMENTS LIMITED  10800902
#
#                                            address1  \
# 0                                     "STREONSHALH"
# 1                              MILLHOLME FARM HOUSE
# 2                     MILLHOLME FARM HOUSE, SPEETON
# 3                                   HILL VIEW HOUSE
# 4                                   HILL VIEW HOUSE
# 5   THE ROYAL HUNTING LODGE SHIPTON BY BENINGBROUGH
# 6                                  6 FEVERSHAM ROAD
# 7                                  6 FEVERSHAM ROAD
# 8                                 62-63 WESTBOROUGH
# 9                               62 - 63 WESTBOROUGH
# 10                                62/63 WESTBOROUGH
# 11                                62-63 WESTBOROUGH
# 12                                62-63 WESTBOROUGH
# 13                                62-63 WESTBOROUGH
# 14                                62-63 WESTBOROUGH
# 15                                        WINN & CO
# 16                                62/63 WESTBOROUGH
# 17                                62/63 WESTBOROUGH
# 18                                      WINN AND CO
# 19                                      WINN AND CO
# 20                                62/63 WESTBOROUGH
# 21                                62-63 WESTBOROUGH
# 22                                62/63 WESTBOROUGH
# 23                                62/63 WESTBOROUGH
# 24                                62/63 WESTBOROUGH
# 25                                62/63 WESTBOROUGH
# 26                                62/63 WESTBOROUGH
# 27                                62/63 WESTBOROUGH
# 28                                62-63 WESTBOROUGH
# 29                                62/63 WESTBOROUGH
#
#                             address2         postTown           county  \
# 0                        KHYBER PASS           WHITBY  NORTH YORKSHIRE
# 1                     SPEETON STREET            FILEY              NaN
# 2                              FILEY        YORKSHIRE              NaN
# 3   CORNBOROUGH ROAD, SHERIFF HUTTON             YORK  NORTH YORKSHIRE
# 4   CORNBOROUGH ROAD, SHERIFF HUTTON             YORK  NORTH YORKSHIRE
# 5            SHIPTON BY BENINGBROUGH             YORK      NORTH YORKS
# 6                                NaN         HELMSLEY  NORTH YORKSHIRE
# 7                                NaN         HELMSLEY  NORTH YORKSHIRE
# 8                                NaN      SCARBOROUGH  NORTH YORKSHIRE
# 9                                NaN      SCARBOROUGH  NORTH YORKSHIRE
# 10                               NaN      SCARBOROUGH          N YORKS
# 11                       SCARBOROUGH  NORTH YORKSHIRE              NaN
# 12                       SCARBOROUGH  NORTH YORKSHIRE              NaN
# 13                       SCARBOROUGH  NORTH YORKSHIRE              NaN
# 14                               NaN      SCARBOROUGH  NORTH YORKSHIRE
# 15                 62/63 WESTBOROUGH      SCARBOROUGH  NORTH YORKSHIRE
# 16                       SCARBOROUGH              NaN              NaN
# 17                               NaN      SCARBOROUGH              NaN
# 18                 62-63 WESTBOROUGH      SCARBOROUGH  NORTH YORKSHIRE
# 19                 62-63 WESTBOROUGH      SCARBOROUGH  NORTH YORKSHIRE
# 20                               NaN      SCARBOROUGH              NaN
# 21                       SCARBOROUGH  NORTH YORKSHIRE              NaN
# 22                               NaN      SCARBOROUGH  NORTH YORKSHIRE
# 23                       SCARBOROUGH  NORTH YORKSHIRE              NaN
# 24                               NaN      SCARBOROUGH          N YORKS
# 25                       SCARBOROUGH  NORTH YORKSHIRE              NaN
# 26                       SCARBOROUGH  NORTH YORKSHIRE              NaN
# 27                       SCARBOROUGH              NaN              NaN
# 28                       SCARBOROUGH  NORTH YORKSHIRE              NaN
# 29                               NaN      SCARBOROUGH  NORTH YORKSHIRE
#
#            country  postcode  \
# 0              NaN  YO21 3DQ
# 1   UNITED KINGDOM  YO14 9TG
# 2              NaN  YO14 9TG
# 3              NaN  YO60 6QJ
# 4              NaN  YO60 6QJ
# 5   UNITED KINGDOM  YO30 1BD
# 6              NaN  YO62 5HN
# 7              NaN  YO62 5HN
# 8              NaN  YO11 1TS
# 9              NaN  YO11 1TS
# 10  UNITED KINGDOM  YO11 1TS
# 11             NaN  YO11 1TS
# 12             NaN  YO11 1TS
# 13             NaN  YO11 1TS
# 14             NaN  YO11 1TS
# 15             NaN  YO11 1TS
# 16             NaN  YO11 1TS
# 17             NaN  YO11 1TS
# 18             NaN  YO11 1TS
# 19             NaN  YO11 1TS
# 20             NaN  YO11 1TS
# 21             NaN  YO11 1TS
# 22             NaN  YO11 1TS
# 23             NaN  YO11 1TS
# 24  UNITED KINGDOM  YO11 1TS
# 25             NaN  YO11 1TS
# 26             NaN  YO11 1TS
# 27             NaN  YO11 1TS
# 28             NaN  YO11 1TS
# 29  UNITED KINGDOM  YO11 1TS
#
#                                              category  status  \
# 0   PRI/LTD BY GUAR/NSC (Private, limited by guara...  Active
# 1                             Private Limited Company  Active
# 2                             Private Limited Company  Active
# 3                             Private Limited Company  Active
# 4                             Private Limited Company  Active
# 5                             Private Limited Company  Active
# 6                             Private Limited Company  Active
# 7                             Private Limited Company  Active
# 8                             Private Limited Company  Active
# 9                             Private Limited Company  Active
# 10                            Private Limited Company  Active
# 11                            Private Limited Company  Active
# 12                            Private Limited Company  Active
# 13                            Private Limited Company  Active
# 14  PRI/LTD BY GUAR/NSC (Private, limited by guara...  Active
# 15                            Private Limited Company  Active
# 16                            Private Limited Company  Active
# 17                            Private Limited Company  Active
# 18                            Private Limited Company  Active
# 19                            Private Limited Company  Active
# 20                            Private Limited Company  Active
# 21                            Private Limited Company  Active
# 22                            Private Limited Company  Active
# 23                            Private Limited Company  Active
# 24                            Private Limited Company  Active
# 25                            Private Limited Company  Active
# 26                            Private Limited Company  Active
# 27                            Private Limited Company  Active
# 28                            Private Limited Company  Active
# 29                            Private Limited Company  Active
#
#                           ...                         POSTCODE_PCDS  \
# 0                         ...                              YO21 3DQ
# 1                         ...                              YO14 9TG
# 2                         ...                              YO14 9TG
# 3                         ...                              YO60 6QJ
# 4                         ...                              YO60 6QJ
# 5                         ...                              YO30 1BD
# 6                         ...                              YO62 5HN
# 7                         ...                              YO62 5HN
# 8                         ...                              YO11 1TS
# 9                         ...                              YO11 1TS
# 10                        ...                              YO11 1TS
# 11                        ...                              YO11 1TS
# 12                        ...                              YO11 1TS
# 13                        ...                              YO11 1TS
# 14                        ...                              YO11 1TS
# 15                        ...                              YO11 1TS
# 16                        ...                              YO11 1TS
# 17                        ...                              YO11 1TS
# 18                        ...                              YO11 1TS
# 19                        ...                              YO11 1TS
# 20                        ...                              YO11 1TS
# 21                        ...                              YO11 1TS
# 22                        ...                              YO11 1TS
# 23                        ...                              YO11 1TS
# 24                        ...                              YO11 1TS
# 25                        ...                              YO11 1TS
# 26                        ...                              YO11 1TS
# 27                        ...                              YO11 1TS
# 28                        ...                              YO11 1TS
# 29                        ...                              YO11 1TS
#
#           LAT      LONG       LEP1 LEP2 COUNTY_CODE COUNTY_DIST_CODE  \
# 0   54.488915 -0.615535  E37000039  NaN   E10000023        E07000168
# 1   54.155893 -0.239788  E37000039  NaN   E10000023        E07000168
# 2   54.155893 -0.239788  E37000039  NaN   E10000023        E07000168
# 3   54.091054 -1.009659  E37000039  NaN   E10000023        E07000167
# 4   54.091054 -1.009659  E37000039  NaN   E10000023        E07000167
# 5   54.051810 -1.166750  E37000039  NaN   E10000023        E07000164
# 6   54.250017 -1.058227  E37000039  NaN   E10000023        E07000167
# 7   54.250017 -1.058227  E37000039  NaN   E10000023        E07000167
# 8   54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 9   54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 10  54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 11  54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 12  54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 13  54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 14  54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 15  54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 16  54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 17  54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 18  54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 19  54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 20  54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 21  54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 22  54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 23  54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 24  54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 25  54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 26  54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 27  54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 28  54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
# 29  54.278977 -0.408069  E37000039  NaN   E10000023        E07000168
#
#     WARD_CODE                                  website  \
# 0   E05006340            http://www.streonshalh.co.uk/
# 1   E05006327                        Website not found
# 2   E05006327                        Website not found
# 3   E05006313                        Website not found
# 4   E05006313  http://www.worldwideshoppingmall.co.uk/
# 5   E05009677                        Website not found
# 6   E05006302               http://www.voyagecare.com/
# 7   E05006302                        Website not found
# 8   E05006317                        Website not found
# 9   E05006317                        Website not found
# 10  E05006317                        Website not found
# 11  E05006317                        Website not found
# 12  E05006317                        Website not found
# 13  E05006317                        Website not found
# 14  E05006317                        Website not found
# 15  E05006317                        Website not found
# 16  E05006317                        Website not found
# 17  E05006317     http://www.scarboroughdialaride.org/
# 18  E05006317                        Website not found
# 19  E05006317                        Website not found
# 20  E05006317                        Website not found
# 21  E05006317                        Website not found
# 22  E05006317                        Website not found
# 23  E05006317              http://www.andrewcowen.com/
# 24  E05006317                        Website not found
# 25  E05006317                        Website not found
# 26  E05006317       http://www.oliversmountracing.com/
# 27  E05006317                        Website not found
# 28  E05006317                        Website not found
# 29  E05006317                        Website not found
#
#                                          social_media
# 0                                               set()
# 1                                           Not found
# 2                                           Not found
# 3                                           Not found
# 4   {'https://plus.google.com/110394507306641485115'}
# 5                                           Not found
# 6   {'https://twitter.com/voyagecare', 'https://ww...
# 7                                           Not found
# 8                                           Not found
# 9                                           Not found
# 10                                          Not found
# 11                                          Not found
# 12                                          Not found
# 13                                          Not found
# 14                                          Not found
# 15                                          Not found
# 16                                          Not found
# 17          {'http://www.twitter.com/tweetdialaride'}
# 18                                          Not found
# 19                                          Not found
# 20                                          Not found
# 21                                          Not found
# 22                                          Not found
# 23                                              set()
# 24                                          Not found
# 25                                          Not found
# 26  {'https://twitter.com/auto66racing', 'https://...
# 27                                          Not found
# 28                                          Not found
# 29                                          Not found
#
# [30 rows x 30 columns]

# %%
ch_nyer['website_2'] = np.NAN
ch_nyer['sm_2'] = np.NAN

# %%
for index, row in ch_nyer.iterrows():
    print(standardise(row[0]))
# Out:
# streonshalhwhitby
# outofthiswold
# clifftop
# 01722212
# worldwideshoppingmall
# 01aa
# 1voyage
# insitetrainingresponsesolutions
# 14museumterracescarboroughmanagementcompany
# 15aberdeenstreetfreeholdmanagement
# 15almasquaremanagementcompany
# 156castleroad
# 2almacourtmanagementco
# 272earlsfieldroad
# 31and33vesperroadrtmcompany
# 35trafalgarsquare
# 6blenheimterracemanagement
# admotorservicesscarborough
# ajstreffordbeverley
# ajstreffordscarborough
# absolutezero
# alexandercourtflatsmanagementco
# alnemewsmanagementcompany
# andrewcowenestateagent
# arrasrestaurants
# attenboroughhotelscarborough
# auto66racing
# autonomoussystems
# ayckbournchaptersmanagementcompany
# basrosdevelopments
# bellehairstudio
# belvederemansionsmanagement
# boatmanstavern
# boydsmillmanagementcompany
# breckonservices
# bromptonholidayflats
# broommillsmanagementcompany
# browconhomes
# catherinegee
# cdvsolutions
# centaurhousemanagement
# cftsolutions
# cheungspropertygroup
# chilternseastyorkshire
# cholso
# cigiit
# cityworth
# cliffbridgeplacemanagement
# cngfoodserviceequipment
# cngtechnical
# corriganleisureproperties
# corriganleisure
# cphlogistics
# crownrenovations
# dandsrenovations
# dpinternationaltours
# dalesideestates
# dawntime
# debramooreassociates
# deswinkscars
# dmasolutions
# dncscaffoldingyorkshire
# dreamswithoutboundaries
# dukesharrisondevelopments
# easbyhallmanagementcompany
# eastridingholdingscompany
# eastridingsackandpaperco
# eastridingsacks
# eastboroughmanagement
# eastgatefisheries
# eatmecafe
# echocentral1management
# esplanadegardenspropertymanagement
# fastockillsonbuilders
# fmglenday
# fandangles
# fileyopticians
# flipsiderocknroll
# floortekntrim
# foundrysquaremanagementcompany
# ganddmetcalfe
# gsanderson
# gardenhurstmanagementcompany
# gaswisetrainingassessment
# gibsonscourtmanagementcompany
# glencourtleeds
# gouldbuys
# grangeit
# graysonhousemanagementco
# greenhandlertrack
# greenhandlers
# greenwoodhandlerhire
# greenwoodhauliers
# greenwoodhire
# greenwoodoperotohire
# greenwoodrotohire
# gwhire
# hcchapmanson
# harrogatehousemaintenance
# hartassons
# healthandwellnessfalsgraveclinic
# hexon
# holbeckdevelopmentcompany
# hornbyproductionengineering
# hudsonwightperformancesailwear
# ilkdevelopments
# ilk
# ilkventures
# incommand
# independentcaregroup
# irtoninvestments
# itsolmanagedservices
# ivesonmanagement
# jeghire
# jegplant
# jblleisure
# jblluxuryleisure
# jenningscomputerservices
# jupiterpublishing
# kdjg
# kelly
# lcmasucci
# lmdaviesbuildingmaintenance
# laneendcroft
# larpoolmechanicalrepairs
# ldwpropertyservices
# lifestylebuilders
# littleboyestates
# littleboys
# londonnortheasternrailwaycompany
# mmhaulageservices
# majorjoinerycaravansundecks
# markjenkinsonscarborough
# maxtone
# mlnortonmanagementcompany
# moorsidegrangemanagementcompany
# mountbooninvestments
# mswsurfacingcontractors
# nrthorpe
# nbrengineeringservices
# northbayfisheries
# northbayrailwaycompany
# northyorkshireaudits
# northernpropertiesscarborough
# northsteadmanorgardensleisure
# northsteadmanor
# overdalefarms
# pmhpromotions
# pmhservices
# pmhsporttravel
# pad25pickering
# parkcourtburleymanagementcompany
# parkithereproducts
# pattersonactuarial
# paulcandlerelectricalservices
# peterkellygb
# phillipsfrenchpolishing
# pickeringestates
# pimmend
# pinewoodsflatsalwoodley
# pinkneygrunwellslawyersliabilitypartnership
# pithersproperties
# property4developments
# rglockwoodelectrical
# rtaitupholstery
# redwizardconsulting
# relustrading
# resinouscastingsyorkshire
# robinsonleisuredevelopmentsplc
# romechspiralsystems
# ronaldcoatesfarms
# rosnet
# staylorson
# scarborovaleting
# sabrinahealthcare
# sandhurstparkflatmanagementcompany4
# sarahssalon
# scarboroughbedwarehouse
# scarboroughconstitutionalclubcompanylimitedthe
# scarboroughindoorbowlscentre
# scarboroughtandoori
# seamerfisheries
# securegreenpropertymanagement
# serenwood
# sevenhillspointmorleymanagementcompany
# sharpeactuarial
# sibccatering
# sirranengineeringservices
# southwolddriffield
# speakersincommand
# srcconstructionandpaving
# stannstowermanagement
# startelevisionprogrammes
# stationviewmanagement
# staycurrentelectricalservices
# stevegosling
# stoneleighcourtleedsrtmcompany
# subaquadivingservicesuk
# sultanstakeaway
# supervine
# synthesysdirect
# synthesyssoftware
# synthesyssystemsengineers
# takefurniture
# teaninvestments
# telehandlerengineers
# thepenthousescarborough
# thephotographicartcompany
# theprinceofwalesapartmentsscarborough
# thevillabentcliffegrovemanagementcompany
# tonypeers
# trentonhull
# valleymanagementcompany
# villatone
# watersidemewsleedsmanagementcompany
# welburnmanorfarms
# westpavillionheath
# whdevelopments
# wilmooreautomatics
# winncoscarborough
# winncoyorkshire
# woodsidecourthorsforthmanagementcompany
# xg
# yamesk
# yorkshirepaperconverters
# yorkshirepremierfinancialservices
# yorkshireprovincialproperties
# 10royalcrescentwhitbymanagementcompany
# 11royalcrescentwhitbymanagement
# langleyflatsmanagementcompany
# numbertworoyalcrescentwhitbymanagementcompany
# regenthousemaintenance
# royalcrescentwhitbyresidentscompany
# royalmansionswhitbyrtmcompany
# 109cb
# rdhengineeringyork
# 11cromwellroadmanagementcompany
# aacommercial
# asedmanproperties
# abeo
# adlelectricalyorkshire
# allaboutmetarvinsands
# amazinpropertydevelopment
# ambassadorhotelscarborough
# ambassadorspahotel
# amgsheetmetal
# andymessrutherjoinery
# animatedobjectscommunityarts
# animatedobjectstheatrecompany
# arbtrading
# asquithcoaccountants
# axeum
# bakerwoodallcommercial
# bakerwoodall
# balmoralhotelrestaurant
# blakeblakeuk
# bluecrush
# bluehorizontechnologies
# borolifts
# browneggs
# budapest
# burnistonmotorworks
# chartleyjoinerybuilding
# cbpoultrytransport
# ccgsupplies
# cfsescarborough
# cityseven
# cleaningetc
# coastalcarers
# coastalgrowth
# coastalrenewableheating
# cockerillsukdrilling
# cogonis
# communitytm
# coppergatekennels
# corrieleeassociates
# cpsenergy
# crosier
# crossgatescarsales
# crowrecruitment
# crownbentleyinvestmentmanagement
# curradi
# djhorsleyfalsgrave
# davescottbuildingcontractors
# deckardassociates
# derwentcarers
# diversorium
# downcliffehousehotel
# downcliffehouse
# eddieprestonbuildingjoinery
# elitecricketequipment
# enmapping
# esplanadevistaview
# eventtraffic
# evolutioninsideout
# fairviewcourt
# fileyveterinarypractice
# firmacconsulting
# firmacengineeringservices
# flixtonsawmills
# floriossd
# foxhoundinn
# franksmithdecorators
# gardnerengineeringservices
# gasdesignmanagement
# gridstock
# hacknesscleaningservices
# hambridgevets
# harricoll
# hbinfo
# hbinfoproperties2015
# hbinfoproperties2016
# hbinfoproperties
# hirstiesbar
# hirstledecorators
# homebuilderscarborough
# hudsonscommissioningservices
# huntsukleisure
# huttonsmanagement
# iainharrison
# iap
# imagnu
# integraholdingsscarborough
# integraholdings
# integraqme1
# integraqme2
# irlmanagementservices
# ithavoll
# iwdmediasolutions
# jambrestaurant
# jhlpropertydevelopments
# jmengineeringscarborough
# jmsdrainsolutions
# jmsmotorservices
# jsfinancialplanning
# juicebitzaudiovisual
# julieblackburnhomecare
# kayshi
# kdengineeringscarborough
# kerrytone
# keydesignelectronics
# kglpower
# kinderplace
# krashlabs
# kridanhandling
# kridan
# lazerradiotaxisllp
# lionhearthouse
# littlefootsteps
# loos2ewe
# mshaulage
# margaretapperleysocialcare
# markbranagan
# marleyagriculturalcontractors
# marshallshotels
# mensdesignerclothesonline
# mfw66
# mikewardmanmetering
# militiaguardmusic
# mobilebarservices
# mrmrthomas
# mustangestates
# mwamspecialistengineers
# nabeal
# newjoe
# northernregenerationcic
# nygdaycare
# nyginterim
# nzak
# pfsadvisory
# plsoundlightingyorkshire
# partnerwisefranchise
# partnerwiseinvestments
# partnerwise
# partnerwiserecruitment
# peaceofmindcommercialfinance
# peachycleanscarborough
# pepeverde
# peterday
# pilfit
# pjstockillplumbingheating
# plannedmaintenanceassosiates
# polarisblinds
# poweredbycustomers
# premiercleaningcontractors
# promechsolutions
# pyramidconstructionmaintenance
# radoproductions
# rawlaw18
# rbcontractors
# regalsecurity
# remotekeyrepairs
# risingbuilders
# risonsoftware
# robstattoostudio
# rocamsafety
# roomsdesignstudio
# ropeaccessinspectionservices
# rumbascarborough
# stinspectionservices
# skscarborough
# sandfieldhousefarm
# scarbattanfarms
# scarboroughbarservices
# scarboroughlifts
# scarboroughmarketcafé
# scarboroughtruckparts
# scarboroughweldingsupplies
# sharpplasterers
# silksfishchips
# skapandi
# smartsoffiley
# spplumbing
# stepneyestates
# stevecarrengineeringdesign
# stirlingrealestate
# streetcarsscarboroughllp
# studioexcel
# swifthrlegal
# sykestrading
# sysdevlaboratoriesuk
# thecardshopmalton
# thecourtyardbar
# thegiftshopthirsk
# theginshow
# thegooddoghouseuk
# theredhousemanagementscarborough
# theskincarenorthyorkshire
# thorgilskormac
# trustplumbingscarborough
# trustplumbing
# uad
# ukweldingservices
# urbannutritionnorthern
# vascotrading
# waterhousebar
# websitemadeeasy
# webexaminer
# whitbyseafish
# winkingwillysrestaurant
# wjpsoftware
# woodlandpavinggroundwork
# yorkshiredotnet
# 11normanbyterracemanagementcompany
# 11theesplanadewhitby
# 19clevelandterracewhitbymanagementcompany
# 2trinityroadmanagementcompany
# 22grosvenorcrescentscarboroughrtmcompany
# 24esplanademanagementcompany
# 3royalavenuemanagementcompany
# 35westbournegrovemanagementcompany
# 46devonshiredrivescarboroughmanagementcompany
# 5grosvenorcrescentscarborough
# 5wellingtonterracemanagement
# 51churchstreetwhitby
# 6allsaintsflatmanagementco
# abrahamsquaywhitby
# adminwisepropertymanagement
# alecharemanagementco
# assigntownpropertymanagement
# berkeleymansionsmanagementcompanywhitby
# blenheimcourtmanagementcompanyscarborough
# carisbrookescarboroughmanagementcompany
# carrhallgardensmanagement
# castleviewapartmentsmanagementcompany
# cranbrookmanagementcompany
# fevershamgatemanagementcompany
# hartfordhousemanagement
# havenflatsscarborough
# heathersidemanagementcompany
# kensingtoncourtmanagementscarborough
# lowstakesbyhouseresidentsassociation
# mcbeanpropertymanagement
# mountsquaremanagementcompany
# normancourtresidents
# northcliffeparkscarboroughmanagementcompany
# orielhousescarboroughmanagementcompany
# pinefloorresidentsassociation
# redhousemanagementwhitby
# riversideviewmanagementcompany
# royalyorkapartmentsmanagementcompany
# sandybedflatsmanagementcompany
# sleightshallmanagement
# southstreetmanagementcompanyscarborough
# southsideapartmentsmanagement
# sthildasterracewhitbymanagementcompany
# stnicholasstreetmanagementcompany
# stjohnswhitbymanagement
# stakesbymanormanagementcompany
# themontaguplaceresidentsmanagementcompany
# threebroomfieldterracewhitby
# trafalgarflats
# unionmillwhitbymanagementcompany
# viewspanpropertymanagement
# watersidewhitbyservicecompany
# welburycourtmanagementcompany
# westcliffstationflatsmanagementcompany
# westsquaremanagementcompany
# whitehalllandingmanagementcompany
# wynbrookcourtscalby
# 117theheadrow
# 27theesplanadescarborough
# bobbycharltoninternational
# christchurchpropertiesnorthern
# citypointleedspartnership
# dbdecorators
# doncasterbusstationholdings
# doncasterbusstation
# egyptreachmanagementcompany
# eptp1175b
# eptp1175c
# espacio
# esplanadeconsultants
# esplanadedirector
# esplanadegroupscarboroughinternational
# esplanadeinteriors
# esplanadeinvestors
# esplanadesecretarialservices
# espuma
# europafrenchgate
# europapropertycompanynorthern
# fairbriarsalfordlanddevelopments
# fairbriarcommercial
# fairbriardevelopmentholdings
# fairbriardevelopmentssalford
# fairbriardevelopments
# fairbriargroupholdings
# fairbriargroup
# fairbriarhatbox
# fairbriarhomes
# fairbriar
# fairbriarmanagementph1
# fairbriarproperties
# fairbriarrealestatedevelopments
# fairbriarrealestate
# fairbriarresidentialdevelopments
# haymarkethousebelfast
# hedleynobleassociates
# johnstreetdevelopments
# lanchestersresidentialmanagement
# middlewoodlocksestatemanagement
# middlewoodlocksresidential
# mlphase2
# quantumpropertypoyle
# remoteproperties1175
# remoteproperties1250a
# remoteproperties1250b
# remoteproperties2100a
# remoteproperties2100b
# remoteproperties2200a
# remoteproperties2200b
# scarboroughuk
# scarboroughacero
# scarboroughbromley
# scarboroughchinaholdings
# scarboroughcrawley
# scarboroughdc
# scarboroughdevelopmentgroupholdings
# scarboroughdevelopmentgroup
# scarboroughdigitalcampus
# scarboroughenterprisecentre
# scarboroughenterprisesuk
# scarboroughfinancecompany
# scarboroughgf
# scarboroughgroupfinance
# scarboroughgroupholdings
# scarboroughgroup
# scarboroughholdingcompany
# scarboroughholdingsuk
# scarboroughinternationalproperties
# scarboroughleeds
# scarboroughmanagement
# scarboroughoverseasholdings
# scarboroughpaisley
# scarboroughpartnership
# scarboroughpartnershipproperties
# scarboroughpropertyuk
# scarboroughpropertydevelopments
# scarboroughpropertygroup
# scarboroughpropertyholdings
# scarboroughscotia
# scarboroughthorpeparkholdings
# scarboroughwatford
# scarfordhirwaun
# scarfordhirwaunno1
# scarmac
# scarnovuk
# scosim
# sdgboston
# sdgcongleton
# sdgglossop
# sdgnewport
# sdgpreston
# sdgrhyl
# sdgstockport
# sdgwigan
# sdgcaledoniaresidential
# sdgireland
# sdgmanagement
# sdgnewco
# sdgpropertyholdings
# seaside1
# sheafmanagement
# sheffielddigitalcampus
# sheffieldunitedhotel
# sheffieldunitedbramalllane
# sheffielduniteddevelopments
# sheffieldunitedgroup
# sheffieldunitedholdings
# sheffieldunitedrealestate
# sheffieldunitedshirecliffe
# sheffieldunitedventures
# smgdonibristle
# spclomondcourt
# spcgroup
# steeland
# sunnydaycapital
# sunnydaypropertyno1
# sunnydaypropertyno2
# sunnydaypropertyholdings
# sunnydayproperty
# sunnydaypropertytradingllp
# sunnydaytrading
# tppropertyservices
# thesunnydaybournemouth
# thethorpeparkpartnership
# thorpepark3175
# thorpeparkdevelopments
# thorpeparkholdings
# tp2005
# unitedscarboroughestates
# usebristol
# usehanoverhouse
# useleicester
# victoriamillsdevelopment
# vservuk
# vservgroup
# vsoftco
# 12bagdalemanagementcompany
# 12boretailoring
# abalphadevelopers
# ahmcenterprises
# dextersmith
# marran
# nctechinsight
# 12esplanadewhitbymanagementcompany
# 12royalcrescentwhitby
# 5normanbyterracemanagement
# critchleymanagementcompany
# eastburyhousewhitby
# kirbyswhitby
# woodlandsmanagementsleights
# 12witheringtonroadmanagementcompany
# 121trainingyorkshire
# 121consultantservices
# 121expressgarments
# 121webdevelopment
# a1communityworks
# commissionanartist
# connectingenterprisepeopletraining
# kidsons
# maddawgmedia
# mapagility
# miniexplorerscrabtree
# mwrad
# picshoots
# pixelvectorapps
# 1212bb
# aceda
# aegiscounsellingservicecic
# amberimservices
# appliedintegrationuk
# assuredadviceservices
# bespokeprofessionaldevelopmentandtraining
# bigfishtuning
# boleroholidays
# brandtaxi
# carltoninvestmentsholdings
# carltonpower
# carltonpowertradingnoone
# carltonpowertradingnotwo
# cateringinstyle
# companyappointment
# cynergyuk
# directfinancialsolutionsllp
# ellerbeckindustries
# ellerbeckstovesfires
# engineeringtalentcentre
# engineeringtalent
# evercal
# gasoil
# gebpower
# geffenconstruction
# geffen
# genesisbrands
# genesisflooring
# genesisglobalsystems
# gibbenscompanysolicitors
# gibbens
# highertrevarthasolarpark
# hornertechnology
# jdcleaners
# keygar
# landscapematters
# langagedevelopments
# langageenergypark
# langagesolarpark
# lordstonesdevelopments
# manorcloseinvestments
# marskemachinecompany
# moneysavingdirectclaimsmanagementllp
# moneysavingdirectpropertyvaluationservices
# moto212
# pettirossiuk
# pinkribbonmarketing
# positiveindividualproactivesupport
# rosedenehardwick
# sensevents
# shawbartholomewdevelopments
# shinymindcoaching
# smartertogether
# steelriverfinancial
# stokesleyproducts
# thorpemarshpower
# traffordenergy
# trustlawdevelopments
# trustlawfinancialservices
# trustlaw
# trustsearch
# tyrekey
# wainstonesenergy
# wainstonesestates
# wainstonesinvestments
# wasteservicesnorthern
# waterswasteservices
# watersealholdings
# zestswainby
# 13bagdalemanagementcompany
# 19royalcrescentwhitbymanagement
# 3abbeyterracemanagementcompany
# aphodgsonfarm
# abbeydrilling
# acedrones
# adeptinvesting
# ady1
# alexandracateringservicesscarborough
# allcaremedical
# altairindustrialropeaccess
# alumgarthminerals
# andybowmanroofcareandbuilding
# arncliffeproperty
# azrawhitby
# bagdalehallhotels
# bitznpizzas
# bkpoffshore
# brookparkengineering
# cjaywhitby
# cjwsafety
# catwickfarmminerals
# conversioncompanylimitedthe
# dannyhayleyfairbank
# darrendobsonjoinery
# dbbuilding
# demrahhplay
# derekatkinson
# dewtel
# diamondplaces
# djhtelecom
# djmhealthcareconsultancy
# donwalkerplumbingandheating
# ecigsguisborough
# egtonbridgedesigns
# elfmarketing
# epcwheelchairs
# eskvalleybuilders
# eskdaleantiques
# eskdalefisheries
# firesfireplacesandstoves
# force10ropeaccessservices
# forevercaptured
# ganister
# grangeassociateswhitby
# greystonesrunswickbay
# hallfarmmineralswhitby
# hallfarmminerals
# hapfieldproperties
# hawthorncourtwhitby
# highquebecminerals
# historicpropertyrestorationwhitby
# hollybushminerals
# inspireandenable
# insurebefore
# ixura
# jcfabrications
# jetblackofwhitby
# jjhughes
# johnhodgson
# justinwaringbuildingroofing
# justinwaringproperties
# kpconsultingandproperties
# keithlocker
# kennelminerals
# lmminerals
# lawrencecross
# lawsongeophysicalaviationuk
# lawsonhobbs
# lopanesquetranslationservices
# mjrigservices
# mcengineeringservices
# marinak
# mariondalefisheries
# martinnarey
# mhminvestmentadvisersllp
# misterchipsholdings
# misterchipsproperty
# mittenhillminerals
# mjlmickley
# moutreyswhitby
# mrduffpotashco
# mwcf
# natureslaboratorymanufacturing
# nbv
# newtonarchitectsdesigners
# northeastecigs
# northeastfishingvessels
# og2016
# pprudomson
# parkesbuilders
# parkesconstructionwhitby
# partridgenestcottage
# philipburleywhitby
# pkswhitby
# plumbtechcleveland
# prestigeperformanceyorkshire
# rjcleaningandmaintenance
# rdattridgebuilders
# rgcanasolidfuels
# rstjay
# rdlscaffolding
# residentsof11brunswickmews
# residentsof82ruswarplane
# rhpsafety
# robindrilling
# roseengineeringwhitby
# rubytuesdayswhitby
# rursusproperties
# rwprojectservices
# ryedalesubseaengineering
# sgwood
# sedmanminerals2012
# selbyservicecentre
# sioffshore
# simpsonsjet
# smokeejoes
# smokeejoessheffield
# stgeorgesecurity
# stewartdavies
# stoupecrossfarmholidays
# swanfarmminerals
# themagpieskitchen
# themetropolewhitby
# theoldschoolhouseresidentsassociation
# timruff
# uncleartfilm
# vtecwindservices
# vortechx
# warpzone
# waterlooplacemanagement
# westcliffedevelopmentswhitby
# westfieldcourtwhitby
# whitbysurfschool
# whitehavensandsendmanagementcompany
# wilkinsonminerals2012
# williamsonminerals
# windoil
# ycctrading
# yeomanestates
# yorkshirecottageservices
# yorkshiremoorsagriculturalapprenticeshipscheme
# zerogravitysurfshop
# 14prospecthillwhitby
# lawsonbuildersandhighaccess
# mspencerbuilding
# 147design
# akecofilm
# abrookconsultants
# altonhs
# bparsons
# bellprideconsultancy
# bestjobsites
# broughmewsmanagementcompany
# broughparkmanagementcompany
# businesscomputersystemsnorthern
# ciengineeringdesign
# captaincookbeers
# cheswoodtrading
# clevelandgynaecologyandfertilitycentre
# constructionandqualityservices
# cooperbarr
# cpccontractflooring
# dalespaving
# endeavourleisureuk
# forensicinterviewconsultancy
# gbunn
# gaintreeproperties
# globalproductsteesside
# greytowersstables
# guisboroughmodelflyingclub
# hartmanninternational
# harveybrooksproperties
# hmdinternational
# hopeaesthetics
# internationalinvestigativeinterviewingresearchgroupiiirg
# jmhareservices
# jeffersoncoconsultants
# juniperengineering
# kcinspections
# kateanddawn
# lpwaltonconstruction
# latelifeplanningnorth
# manorhouseacquisitions
# manorhousecommercialacquisitions
# markgrahamtechnicalservices
# mulcasterbarrattengineering
# northerndalesfarmersmarket
# popcorn
# postkogekoperishables
# professorraybullassociates
# rtjhservices
# redcarandclevelandtrainingcentre
# robertsandhampavingcontractor
# rollerhomes
# srslushcompany
# sarkco
# sjresources
# slclservices
# solearthsystems
# spiritofcaptaincook
# starvocals
# steadmanrose
# steamreformingservices
# stemardevelopments
# strategicdeliveryassociates
# taylorfoster
# thebaybrewery
# thorpparkerllp
# thyone
# utbnb
# vanduijntransport
# vectorconservation
# vectorsalesmarketing
# walltransform
# walworthcastlebirdsofprey
# walworthfalconryservices
# warmawall
# whiterosetaxis2000
# wiseincome
# 149barnardcastle
# 149bridlington
# 149catterick
# 154castleroad
# bronte158properties
# drjosephbazmedical
# jmjpetroleum
# 16bellevue
# abdhopkins
# balmainenterprises
# belconcivilengineering
# booksbythebeach
# brackencliffescarborough
# constructionbuildingservices1994
# crownsurfacing
# customcallscarborough
# danedevelopments
# dawsonwake
# dawsonwakeproperties
# gamequest
# gatewaysdevelopments
# gemscarborough
# hawkinswolf
# identityyorkshire
# indieapparel
# indieicon
# kcprecisionengineering
# northcliffeheightsmanagementcompanyno1
# pwamanagementcompany
# patchworkenergy
# pelholdings
# pweheatpower
# raynerco
# routeoneproducts
# scarboroughdistrictmotorclub
# scarboroughbookfestival
# scarboroughdecorators
# sinco
# themooringsmanagementfiley
# wubutterfieldcaravanning
# yorkshirecoastgigscic
# 16highstreetpropertymanagementcompany
# cooksandkitchenskitchenware
# mhthwaitesbuildingrestoration
# 17abbeyterracemanagementcompany
# abbeyfourwhitby
# abbeyterracemanagementwhitby
# 1718haggersgatewhitby
# 18esplanadegardensmanagementcompany
# 182ashmoreroadmanagementcompany
# 3pholdings
# abheatingservices
# albertsutton
# albionrestaurants
# alpinebay
# alvercroft
# angloacademy
# anglolangscarborough
# antonscafebargrill
# artisandesignco
# aspirehomesyorkshire
# bdsiteservices
# beeversbeds
# beeverswhitby
# blindtech
# burdasslamb
# capernum
# castleplan
# chakkanaturals
# coastaldetailing
# compasshealthandfitness
# cthwealthmanagement
# djhorsleypickering
# discoveryaccommodation
# dusrolbake
# electrodec
# escobarbay
# fersinanorthyorkshire
# freyerwilsonestates
# gcollinsonconstruction
# gopropertyleisure
# helenerobertsontranslations
# horizonbay
# hugginsbeaumontdevelopments
# ianpickuptransport
# immersivescanning
# independentshellfishermenscooperativebridlington
# infinitiroofing
# infinitiscaffolding
# infotoneimagingsupplies
# inghamcoservices
# inghamsoffiley
# ipcrestproperties
# jcwatsonandson
# jimmycorrigans
# knipepointfreeholders
# knipepointownersassociation
# legalandtechnicalassessors
# logolightflatmanagementcompany
# lordcorriganpromotions
# mpinderjoineryandfencing
# madhattersearlyyearscare
# maxpowerelectrical
# mknsurveyors
# nandmfletcher
# naylorsnewsagents
# northbaydesigns
# oakscliff
# offpistetaverns
# pandshobbiesandmodels
# plusmarkservices
# primebiotics
# provisage
# psprojectengineeringservices
# robertheaps2010
# rstlogistics
# russellprojectservices
# ryedaleburnerservices
# scfishing
# saxonparkownersassociation
# seniorholdingsscarborough
# sheadermedia
# slotsrus
# southlundproperties
# starfishaccommodation
# surveyshopwhitby
# sylviawrigglesworth
# twtindallson
# thegoodallgroup
# theyorkshirelobstercompany
# u4coffee
# unitedengineexport
# wmjdevelopments
# wlawrenceandson
# wainstoneshotels
# walkerhuttonholdings
# walkerhuttonscarborough
# walkerelectricalscarborough
# wilsonvalentine
# wrenscontracting
# 19brooklands
# resonus
# 1stdegreeheatingandplumbingservices
# 2arches
# blackseaplaza
# deemproperties
# 2bellevue
# andyprestontailoring
# bagniamici
# bolterdesignllp
# dreamstoreacademy
# ecclestonsquaregarden
# everythingtowellingcom
# highparkfarmllp
# rockerydevelopments
# tastesofitaly
# theravenswickshoot
# williamgoodacresonswine
# 2broomfieldterracewhitbymanagementcompany
# blueprintpropertymanagement
# greshamboon
# squapp
# swiftassociates
# 2nicks
# apsedman
# adfbuildingcontractors
# adlightfoot
# a1microwavegroup
# abouthouse
# accessoriesbyparklane
# acselectricalyorkshire
# acurabuild
# ahteneds
# ajdmedicalservices
# alexlange
# anjbservices
# ascperformance
# bmwatson
# badseedbrewery
# bigbearbikes
# bjlyorkshire
# blb2012
# brmservicesnorthern
# bryomar
# cbtclinics
# crjbooth
# crvgrice
# cafefishscarborough
# calplant
# castlecarpetsyorkshire
# cedarstudiodesigns
# charlesporterclassiccars
# cn2013
# coldwatereconomics
# computerfx
# costellosdriffield
# costellosmalton
# costellospocklington
# costellosuk
# costelloswetherby
# costellosbakery
# costellossalumeria
# cyrusmotorcompany
# dae20152
# davedavis
# davefisherwindows
# dbgagriculture
# dennis
# derwentgarage
# desirablenails
# erassets
# elanevdata
# evergreentreesandshrubs
# expertpsychologicalreports
# fjhodsmansons
# fashionablefitness
# fisherbrothers
# floriosmalton
# freshmetal
# gwisebarsupplies
# generalpractitioners
# georgepender
# gillhallprojectmanagement
# gmcfiresecurityprotectionservices
# grxsolutions
# hartleydevelopmentsyorkshire
# holmefieldfarmservicesyorkshire
# holmefieldveterinaryclinic
# horsleymarketgardening
# hovinghambakery
# huddlestonefarming
# iddevelopmentsyorkshire
# indiamalton
# iqmicrowave
# jrobinsonson
# jwsmithco
# jayalexander
# jmdtechnologies2010
# jmdtechnologies
# kfscott
# kartecnorthern
# kingshallleisure
# knightsinvestmentmanagement
# kpiprosync
# laserempire
# ldstechnologiesuk
# livewiresclub
# mgbrook
# mnbjoinery
# mskmthomas
# mva
# maltonmontessorischool
# maltonplumbingandpropertyservices
# markstephensonco
# medwaysecuritywholesale
# meipumpservices
# mercuryhmi
# michaelandrewofyork
# milleniumconsultancyservices
# mjbowdenlocations
# mooncoinconsulting
# ndcrummack
# networkroylerecruitment
# newflowyorkshire
# newflow
# no1healthbeauty
# northyorkshiremanagementservices
# omniflowcomputers
# pacuthbertson
# partnersinpackagingmachinesystems
# paulabeal
# paulchaplowplumbingandheating
# plumtrading
# poundstockengineering
# powercopowersystems
# powercosystemsinternational
# premierengineeringcorporation
# pscewall
# pyramidmasterbuildingsequipment
# rsmarton
# rdeventsandconsultancy
# rhthompsonson
# rjctodd
# rwbettison
# rwbettisonproperty
# rachelmclane
# railtecuk2014
# ralloyengineering
# rkmplumbingheating
# ryelabs
# ryecomp
# ryedaletradewindows
# ryedalevapour
# sjcladdingsolutions
# sanchuridesign
# sjrcontracting
# sph20151
# stephenfreerelectricalcontractors
# supersewimports
# suttonabattoir
# tmhogarth
# tabuhairdesign
# teslaautomation
# thedocumentpartners
# thefabulousmeatandfishcompany
# thegymkingholdings
# thegymking
# theolivetap
# tknowit
# townsendharrison
# wpegram
# wathcourtnursery
# whartonamusements
# whartonleisure
# wolfstonecapital
# yorkshiredrones
# yorkshiregiftware
# yorkshirehandlers
# yorkshirerallyspares
# 2ridleyroadmanagement
# 2stpeterstreetmanagement
# radishcommunications
# 20glenrosastreetfreehold
# jeddokeefferacing
# theforbiddencorner
# 2020marineenergy
# bluedefenceandsecurity
# knet
# mybuildersyorkshire
# seavegate
# ukvenisondeerfarming
# 2021consulting
# beverlyhillstrading
# coolindustries
# coolrealestate
# cooltrucks
# globalholdings
# rockcastleagriculture
# shirecountryservicesllp
# thebeverlyhillsgroup
# tokyoandyork
# yokohamaandyork
# yorhold
# 206210northgateliabilitypartnership
# bakerbakerdevelopments
# citycommercialpropertycompany
# cliffvalley
# landteamdevelopments
# landteamfarms
# landteamnorthern
# landteampropertyinvestments
# northbynortheastfilmservices
# northbeckhouse206210northgatellp
# rollaturf
# theorchardstreetbusinesscentre
# turkeymillestate
# turkeymillinvestments
# tyasturf
# urbanruralinvestments
# 21trafalgarsquaremanagementcompany
# 83nelsonstreet
# 9496hoxtonroad
# agnesgreyhouse
# arlingtonapartmentsscarborough
# avenuevictoriaflatsmanagementcompany
# bedfordcourtmaintenance
# belgravemanagementcompany
# bravendercourt
# charleswilliamapartmentsmanagementcompany
# edgewoodscarboroughmanagementcompany
# eltomeapartments
# fairviewcourtmanagementcompany
# headlandview
# hunmanbyhallnorth
# marinesands
# marineviewapartments
# northcliffeheightsmanagementcompanyno2
# olivercourtresidents
# pavilionview
# roasterscoffeecompany
# rosevalecourt
# 22esplanademanagementcompany
# appletonpowercomputingservices
# intellipos
# technicalassessorservices
# 23bowerroadmanagementcompany
# mabenvironmentecology
# mark1123design
# 235highstreet
# allertonpizza
# hollywoodnailcentrenorthallerton
# placeblairhatch
# yorkshirefireplaces
# yorkshirefirewood
# 24crescentavenuemanagementwhitby
# sparklingwaters
# 24lanhillroad
# 26eastborough
# agrademanagement
# ahillhorsetransport
# atouchofglassscarborough
# aemclaytonscarboroughlimited
# agpennock
# activityparks
# aestheticsbybree
# albioncottagesholidaylets
# andykinchinc
# apusfilms
# arborconstruction
# arborcustomhomes
# arborhomes
# ashbyberrycoulsons
# bmfootingspecialists
# basiteengineering
# barvisavis
# barnesagencies
# behzco
# bellsnoxellbuildingconsultants
# belvedereplacemanagement
# bettamotoring
# beverleyhouseracing
# bhiorainhydro
# blockbookers
# brglobalproperties
# broadfall
# byeck
# caddiesscarborough
# cadoganbramleyhotelslimited
# camghleannhydro
# casterbridgemanagement
# castlehotelservices
# cathygannon
# ceitleinhydro
# chanceland
# chaorainnhydro
# charnanhydro
# cijcommunications
# clarkeprojectsyork
# clayscatering
# clivedavies
# colourcreation
# coulsoninvestments
# coulsons
# crazycombat
# dkdevelopmentsscarborough
# dflawlor
# dpleisureleeds
# daisybridge
# davidfletcherfinancialservices
# dentexceluk
# derwentdalefarming
# dexterssurfschoolhirecentre
# dickinshydroinvestments
# dickinshydroresources
# dissent
# djmnetworks
# donfrenchsigns
# dpengineeringyorkshire
# eappleyard
# eastpro
# eckiethump
# ecseventsconstructionspecialists
# edgehydroholdings
# edgiltonhotels
# edgiltonpropertycompany
# exclusivemediaeurope
# exleysmithelectrical
# eyrescaffoldingyorkshire
# faceuk
# fernhilldevelopments
# fhaolainhydro
# firmacinternational
# firmac
# firthsheetmetal
# floriosscarborough
# gantongreyhoundyorkshire
# gaoireanhydro
# garnettelectricalscarborough
# gemmadarleyphysiotherapy
# gksteelservices
# glenetivehydrogridco
# goldennightfinancetradingco
# graysonfire
# greengator
# hhscarborough
# habtonfarms
# handheldcineclub
# hovinghamstores
# ilyasmedicalservices
# interpersonnelhr
# ittakestwo
# ivybankdevelopmentsscarborough
# jadrivingtuition
# jvsleightholme
# j3pso
# jesfarming
# jjquinnracing
# johnmitchellofficeequipment
# johnsonelectrical
# keithhansonjoinery
# kgservicesyorkshire
# ladybirdcleaningcompany
# leeelectronicsengineering
# limapropertiesscarborough
# lungfungcrossgates
# mksoftdrinks
# magicmike
# manorhotelswinchester
# markheslington
# medoptimise
# mheuranhydro
# mickblythbuilders
# modularplantrooms
# morleyminerals
# mppipework
# ndlelectricalscarborough
# nickfletcherelectrical
# nortongrovestud
# oaksfarmstables
# oasisrestaurant
# olliepearsracing
# otwayjoinery
# pfarrowandsons
# psaltplasteringcontractors
# parsproperty
# paulscottjoinery
# penguinuk
# phoenixbuildingcontractors
# physicaleducationrecordings
# planusualprojects
# premiernorth
# prillyspantry
# psdscarborough
# quantumredevelopments
# quietindustries
# rpbhunmanby
# rfracing
# rjrmarley
# roshjewellers
# russellsminimart
# ryedaledentalhealthcareclinicimplantcentre
# ryndlecourtproperties
# srjdevelopmentsyorkshire
# srsdevelopmentsscarborough
# scocking
# seblet
# swrceramics
# sabrecourt
# sambran
# santangeloresources
# scarboroughliberalclubhousecompanylimitedthe
# scarboroughpages
# shadowmancer
# sinatraswing
# sivaspickering
# spiralbend
# springforwardconstruction
# steveborrieservices
# stittenhamfarms
# stittenhamracing
# superswimacademy
# swordsandpistols
# tsmasonrystructures
# tbbratleyson
# thefirthfirmacgroup
# thesignworkshop
# thesmithyarms
# thomasdefencesystems
# tomwhiteplumbingheating
# totalk9
# victorialaw
# wbellisonsonhunmanby
# wardlejones
# wavesscarborough
# webequine
# west8architecture
# westhighlandservices
# whiterosesaddlery
# whiteridge
# windowworksyorkshire
# windsortownhorsedrawncarriages
# woodstreetmanagementcono2
# wordofmouse
# wrencottage
# zerogravityoutdoors
# 247carfinance
# almightysports
# aurcymru
# bigmouthmediayorkshire
# braidness
# brookecatering
# brownandcocertifiedaccountants
# calfsanctuary
# cred
# georgemichaels
# greycatquality
# i330
# ipoddoctor
# ipoddoctorrepairs
# iqaccountants
# jonty
# lbasoftware
# loafersshoes
# mspalmerplumbingheatingservices
# nicksimpsonsons
# northstar
# proactivefinancialmanagement
# professionalconnectionconsultancy
# redcurrant
# richardsimpsonyorkshire
# savethefuturisttheatrescarborough
# shorelinesuncruiserbuses
# skpbusinessservices
# theinkloungebar
# theyorkshireteahouse
# tomtomtomato
# valletaholdings
# 25crescentavenuemanagementcompany
# 25yorkersgatemalton
# apiceuticalresearchcentre
# audreys
# bmjhomesco
# boggbros
# bsfabricationsuk
# certushealth
# cranevintage
# g25developmentsco
# hartinnleisure
# heritageenergy
# jonesfoodcompany
# keldkommercialservicesco
# maltonplasticsuk
# marshallsteelbuildings
# mcspdesign
# prolinepvcu
# ratedart
# resetcompany
# ryetools
# smartsolutionsyorkshire
# technicolourppc
# thejonespartnershipnorthyorkshire
# thenorthernenterprisecentrecic
# theoldmillenergy
# thorntoncollins
# ukelectronicrepairco
# waterandrescuetraininguk
# 26clabonmews
# 31cathcartunlimited
# acerdex
# arbingtonuk
# arlafilm
# barresta
# belfernuk
# besfield
# bodell
# buddington
# cisensor
# coleviewpropertiesno1unlimited
# cresslake
# culmproperties
# cuthalux
# delfreston
# delladex
# dormlands
# eakins
# eweproperties
# fernesta
# fernlane
# frenchcoastvillas
# goldencentre
# goldenmar
# havenhead
# jettington
# lerringford
# lipsylem
# lumatex
# lunadee
# lynnelandpropertiesunlimited
# malew
# melanor
# menthemoor
# metendop
# moleproperties
# montpeliertrustees
# montpelieraudit
# montpelierpensionadministrationservices
# montpelierprofessionalborders
# montpelierprofessionalsheffield
# montpelierprofessional
# morrington
# newquayprofessional
# opencrm
# palmerparkerllp
# partou
# pelforce
# petalville
# portisfield
# portismere
# preleaf
# ramlane
# ramlexuk
# rawledge
# realagent
# rellismere
# remfall
# rempton
# resinlake
# rinthor
# rollisfort
# rosaland
# ruthamoor
# solventor
# tanushter
# tareck
# tarragoni
# tefline
# thorpenna
# traden
# turnidor
# turrox
# viewscrestuk
# villaconnections
# warlake
# wartech
# webconnection
# wellam
# 28rutlandstreetmanagementcompany
# fileybirdgardenanimalpark
# 290crew
# rdtechnicalservices
# twwalker
# 2bsclublimitedthe
# kidscoscarborough
# theyorkshiretappublichouse
# 3albionterracemanagementcompany
# northyorkshiredriveways
# 3southdene
# 32maisondieumanagementcompany
# andream
# anthonyburkejoinery
# boominnovation
# clrlocumservices
# kissthemoon
# mbdesignanddevelopment
# 34rutlandstreet
# 90trinityroadbridlingtonmanagementcompany
# allseasonswholesale
# ambrosiavillamanagement
# baycourtsmanagementfileylimited
# bridlingtonescape
# churchclifffarmmanagementcompany
# deepdenefileymanagementcompany
# eastcoastflatsfiley
# fileychapelmanagementcompany
# fileycommunitysportsclub
# hrf4hr
# hrf4property
# hunmanbyhalloldhall
# hunmanbyhallsouth
# jcsolutions
# newtoncourtfileymanagementcompany
# normantonrisemanagementcompany
# royalcrescentcourtbridlington
# southcrescentcourt
# swisscottagecourtmanagement
# universalenglishlanguageservices
# xennochangemanagement
# 36esplanaderoadscarboroughmanagementco
# 36rutlandstreet
# 37holdings
# ageckouk
# bearexports
# colourheroes
# colourhistory
# easiexportsllp
# easirecyclingservices
# ebidesign
# limecoast
# ukcasemanagement
# vestigoprivateinvestigations
# 38noelscourtmanagementcompany
# 3edgesworkplace
# armstrongsafetymanagement
# chronosaeon
# gstassociates
# jobstopper
# keenengineering
# nastavnik
# pluckmusicagency
# stocktonelectricalservices
# tlhcontractors
# workplaceadvantage
# 4churchsquarepropertymanagement
# 7churchsquarewhitbymanagementcompany
# 4mori
# 521media
# ajbdriverservices
# abfabrications
# advancedigitalyorkshire
# aelscarborough
# alangreavesconsulting
# alexanderterracemanagementliverpool
# allfinancialadvice
# alloyplant
# americandiningyorkshire
# andyswindowcleaningservices
# automobilegarageservices
# awgeneratorservices
# bjdevelopmentsscarborough
# bakerprinters
# balochmedicare
# barrydixon
# beckettinvestmentmanagement
# bigredcurtain
# blakestonplumbingheating
# blueskymd
# bonnetschocolates
# bonnetscoffeeshop
# bothamfiresecurity
# brianjacksonmanagementservices
# cdservicesscarborough
# csaltscarborough
# caadlocum
# cadmantechnical
# callcentrecommunications
# carlyperryactuarialcontracting
# cbceilingsscarborough
# chtsolutions
# clenterprisesyorkshire
# clmrenterprises
# cmdsales
# compassadvisory
# conceptconstructionevans
# conceptconstructionscarborough
# cougarssportsbar
# courtyardadministration
# coywood
# ctrlware
# dgphillips
# dfstrainingservices
# dicconsonproperties
# dineamericaleeds
# dineamerica
# dineamericayeadon
# dineamericayork
# diningmanagementservices
# dixonwayestates
# doughtyarchitectural
# dpsintegro
# dsalocums
# duasconsultancy
# emce
# eastgrinsteadtenniscoaching
# eastyorkshiregasserviceshull
# eastgategarage
# emcesolarsolutions
# energyc
# expresscoachrepairs
# fcgarageservices
# f1investments
# fairbankthebaker
# flooringinstallations
# floortechofscarborough
# grbuildingmaintenance
# gameonrearingsupplies
# granbyhotel
# gratongt
# greavesfinancialservices
# grimesshellfish
# hjslingerconsulting
# haverfieldestates
# haversnax
# haystead
# hewitsonbayles
# huckleberrysrestaurantsdarlington
# huckleberrysrestaurantsyork
# hussainenterprisesyorkshire
# ikwelding
# icoinvestmentcompany
# imaginativeicing
# ismengineeringnorthyorkshire
# jwhmgraham
# jwburlinsonprojectdevelopments
# jitterbugsnursery
# johnsonmedicare
# johnsonsupholsteryfurnishings
# jowsoncorporation
# jwsfinancialmanagement
# jwstrusteesnominees
# kandrproperties
# kjbrownjoinerybuildingcontractors
# lawrenceneilwealthmanagement
# ldmconsultancyservices
# leesmythconstruction
# longtermcarecoach
# lucyholdings
# mjboyerssons
# markwhiteleyholdings
# masonsofwhitby
# mclarenrts
# measuretime
# merrydithpropertydevelopments
# mickeythebrickey
# mikekentcarvansalesscarborough
# mkbusinesssupport
# mrenterprisesyorkshire
# muhammadalimalik
# myelectricalnorthern
# nabeelhussain
# netnine
# northeastsolutionstogether
# northstreetgaragescarborough
# northyorkshirefinance
# northyorkshirersspares
# pcdaleysmith
# parrsfoods
# peakholidaycompany
# perrysplants
# philprintscarborough
# polishedfroginvestments
# processpiggingsystemsuk
# rcammish
# rnightingale
# rlestates
# ramsdalefarm
# ramshillfisheriessouthcliff
# redskymd
# richardjacomb
# rockymazs
# roogreenventuresllp
# rosgrimeshellfish
# rowntreeplayers
# rvconsultingsolutions
# rvruk
# spdarwell
# saimedicare
# scarboroughcarpetcentre
# scarboroughflooring
# skids4kids
# smilesmiddlesbrough
# sunsethealthfitnessclub
# sweetingengineers
# sweetinginvestmentco
# sycamore
# tedaughters
# tantrim
# taylorasiaresearchcentre
# theaerialphotopodcompany
# thecastironbathcompany
# theflowerpotwhitby
# thegafplaycentre
# thegladstoneandfalsgravecommunityplaycentre
# thescarboroughhotel
# thinspirations
# thompsonsfishchipsa64
# traditionalbathroomcompany
# trevorwharton
# universalqualitysolutions
# wrgmotors
# wheatcroftgarage
# williamhodgsonsonsmotors
# windytreeventures
# wreaheadholidaycottagellp
# yorkshireclassiccamperhire
# younghudson
# yumtums
# 4windsorterracemanagementcompany
# 4thecrescentmanagementco
# aguksolutions
# allpointselectricalservices
# askewbrook
# auracreativemedia
# axisfinancenorth
# axisware
# bettaautos
# c3events
# coastcountryplumbingheating
# combineddesignsolutions
# createartsdevelopment
# creativeindustriescentretrust
# dalbyactivitycentre
# davelucaselectricalservices
# dsntechnologies
# edwardmilnesaccountancy
# eimedia
# evohold
# fitzpatrickdesign
# heritageadventures
# historichotelsproperties
# invisibledust
# jellyboycreative
# krbuildingservicesscarborough
# kdrecruitment
# kirkhamgroup
# kirkhamplastics
# lùthconsulting
# maccmusic
# makebelievetours
# manorroadstoresscarborough
# monkeyandbutler
# nolanpropertylettings
# raincliffewoodcommunityenterprise
# rjbusinesscoaching
# roughshotsproject
# rudradevi
# samcartwrightjoinerybuildingcontractors
# scarboroughmuseumsandgalleryenterprises
# scarboroughmuseumstrust
# servertastic
# servertasticwebservices
# simplewords
# smartprintsupplies
# thebigbeat2
# theholeinthewallscarborough
# ukfoundationfordance
# valleypress
# vickysbar
# villagerecords
# worldfederationofhealingcommunityinterestcompany
# 43westavenuefiley
# fairmount88
# fredericklawther
# minimalton
# rhltconsultancy
# rosform
# thebikelockcompany
# yobakehousewholesale
# 442motivation
# busbystoopcarcentre
# busbystoopgarage
# jaipurspicelounge
# thebusbystooppartnershipllp
# 4serve
# andrewseagust
# aquapoint
# arcelectricaluk
# scothernconstruction
# thetofoocompany
# 4uktm
# ahardytrafficmanagement
# asmythetm
# awrighttrafficmanagement
# a2btrafficmanagement
# actiongt
# actmstrafficmanagement
# adftm
# ajbtm
# ajldriverhire
# ajmtm
# altrafficmanagement
# always
# amontm
# argonizationtm
# aronstanleytm
# arttrafficmanagement
# ashleyemcintosh
# asttrafficmanagement
# atacktrafficservices
# awtm
# bmanntm
# brobbotm
# bacdriverservices
# barnetttrafficmanagement
# barrymcnamaratransport
# benny1984
# bharttm
# blmtm
# bmptrafficmanagement
# bpjtrafficmanagement
# bpwtm
# brownlietm
# bryntrafficmanagement
# bsbtm
# byrnecontractdriving
# cashworthtm
# cbradylogistics
# cjedwardsenterprises
# clincolnlogistics
# ccunni13tm
# carnieloperationssupportservices
# cdjstm
# cherrimantransport
# christineenterprises
# cittm
# cmkctm
# cobraflow
# conetoptm
# cpbtm
# cptmservices
# craigjoneshaulage
# crazyfrogtm
# csqlogistics
# csrwtm
# csslogistics
# cwstm
# cyltm
# dchurmtrafficmanagement
# dcoletrafficmanagement
# dknoxjoinerycontractors
# dmillsomtm
# dwheatcroftcommercial
# dabeksonstm
# daggtm
# daleheatingsupplies
# dbtm
# dbbtm
# dcttrafficmanagement
# ddltrafficmanagement
# deeringtm
# demicotm
# dfltrafficmanagement
# dgtrafficmanagement
# djrtm
# djwtm
# djwbtransport
# dlhtraffic
# dnmtraffic
# douglassocialwork
# dowelltrafficmanagement
# dptm
# drawtm
# dretm
# dtmtm
# dwmdrivingservices
# dyoungtrafficmanagement
# edelaneytm
# embtrafficmanagement
# embertontransport
# evanjward
# excelplustrafficmanagement
# fastlaneperformance
# finklestreetproperties
# foxtmservices
# fozzatrafficmanagement
# gwylamtm
# gmpiersongroundworks
# gwtransportconsultants
# garycdeering
# gdtrafficmanagement
# generalpersonalservices
# geraldfogartytm
# gpdtm
# gtmstm
# gustransport
# harveyraytm
# heathtrafficmanagement
# hessonhaulage
# hewitthaulage
# hispeedtm
# hindsightcontractors
# hourstonlogistics
# ifoxtrafficmanagement
# iwarrenlogistics
# ianlittletransport
# ianogdeninternationalhgv
# irslogistics
# jhtrafficmanagement
# jrobertstm
# jeggintontm
# jactrafficmanagement
# jadtm
# jagtrafficmanagement
# jambuttiestm
# jamescousinsgolf
# jamesturnertm
# jamiechloe
# jbbprojectmanagement
# jboburden
# jcctrafficsolution
# jdkhaulage
# jettm
# jjtttrafficmanagement
# jletm
# jlrlogistics
# jmhtm
# jmstm
# johnwallstm
# johnnydealertm
# jonestrafficmanagement
# josalftm
# jptm
# jpctm
# jrbtrafficmanagement
# jrplogistics
# justthejobenvironmentalenterprise
# kbagleycontracting
# kswiercztm
# kadtscoservices
# karlnewmancontracts
# kbmcstm
# kdtm
# kennethmckelvey
# kerfootdriversservices
# kitrafficmanagement
# kirwinlogistics
# kjwlogistics
# kmktm
# kmvtm
# kprlogistics
# ktmtrafficmanagement
# ktwtm
# losbornetm
# lawrencedriving
# lbflogistics
# leeshatm
# leoesmetm
# lgflogistics
# lhtmmanagement
# liammufc
# ljatm
# lkttrafficmanagement
# llltm
# lttrafficmanagement
# lukerobertstm
# lwshaulage
# mandktm
# mcavetrafficmanagement
# mdeanlogistics
# mirelandtm
# mjheadtransport
# mkcontractservices
# mlistertransort
# msaunderstm
# maetrafficmanagement
# majtrafficmanagement
# martrafficmanagement
# markorrelltrucking
# martinyoungdriving
# mattballarchitecturellp
# mattballservices
# matthlogistics
# mauranaexport
# mctm
# mcnicholaslogistics
# mcttrafficmanagement
# metms
# mgdtm
# miagtrafficmanagement
# michaelhalletttm
# midlandstm
# mjbrownsurveying
# mjctm
# mjmtrafficmanagement
# mjotm
# mlbtrafficmanagement
# mortontm
# mpptm
# mpptrafficmanagement
# mrbtm
# mtelogistics
# mtwtm
# ndjstrafficmanagement
# nikotm
# njltm
# njptm
# njwtrafficmanagment
# notoriouslogistics
# ntttlogistics
# ogdentransportmanagementservices
# ohlssontm
# ormrodcommunications
# orpinlogistics
# osiristm
# oxquefarms
# phcrainelogistics
# pcoxtm
# pkharding
# pstokestransport
# pahlogistics
# pcctm
# pdbwtm
# phdhaulage
# placesecurepropertymanagement
# pmdtm
# pobtm
# purelinesystems
# pvblogistics
# rwhitetm
# rdctm
# rdptm
# rigbyandfamily
# rivenreevetransport
# rlsmithlogistics
# rmktraffic
# robtravistransport
# rpgrtm
# russellstransport
# rwlogistics
# rwfhighways
# sbrowntrafficmanagement
# sgranttm
# smuldown
# ssertrofpropertyrentals
# sadtm
# samitrafficmanagement
# sammycaulfieldtransport
# sammygrafttm
# sdmtms
# sdrtm
# sebastianenterprises
# sectm
# sfltm
# sjohaulage
# sjrtm
# slctrafficmanagement
# slipinndevelopments
# slrtrafficmanagement
# smhighways
# smdhaulage
# smdtransport
# smetrafficmanagement
# spaceonlyinstallations
# speighttransport
# spennybarn
# steventerry
# stothartlogistics
# stubbstrafficmanagement
# suesbarbershop
# swaleedge
# sykotrafficmanagement
# tjacksontm
# tbmtm
# tetransport
# thepayrollfranchise
# theshowcasegallery
# tiswindytm
# tonystscosolutions
# trenttm
# tsgtm
# tyasenterprises
# vdaviestransport
# wdhadwintm
# wdanielstm
# wwilliamshaulageservices
# whiteleytrafficmanagement
# whittletm
# wildentm
# wkftransport
# woodcocktmservices
# wortontm
# wpltrafficmanagement
# wrightytrafficmanagement
# xtm
# 4x4accessoriestyres
# 5windsorterracewhitby
# discoveryminibushire
# markstringerbuilding
# 50degreesnorth
# a2btaxisnorthallerton
# acklamhallestates
# acklamhallmanagement
# aldbroughelectricalandtechnicalservices
# allanrichardsoncommercialvehicleengineers
# altbergholdings
# apexmedicallocums
# arbfortraining
# arburton
# assetlocation
# btkitson
# baandcpearson
# bentyclose
# bespoketrainingsolutions
# brierleyevents
# candstyres
# cwrussell
# catterickservicestation
# centredexcellence
# chipsandthings
# christopherwilliamsplpbarrister
# classicexperiencespitlochry
# classicexperiences
# clevelandclearwaste
# cmhconsult
# constellationbuildingjoinery
# coretechsports
# criticalpathsolutions
# dacosmetics
# darlingtonroofingcontractors
# darringtonholdings
# devinculis
# deantransportservices
# debmatsurfacing
# deptstudio
# directconnections
# directsavingsnortheast
# dtnortheastllp
# duntonpropertiesuk
# emmaldixonclinicalpsychology
# energessenergysolutions
# espresso10
# fairbairnblack
# flexicad
# freshmedicalgroup
# freshrecruitment
# garrisonvanhireremovals
# garyappleton
# graceyarchitectural
# grahamfaulknerbuildingjoineryservices
# grangeroadpropertiesmiddlesbrough
# gunsoncoindependentfinancialadvisers
# harelandsmelsonby
# harelandscourtyard16
# harryspence
# hassiumgroup
# hebburnsportsclub
# hewetsonjohnson
# hibbertcrownandbridge
# holmedaleconstruction
# horsfalls
# hrwizard
# hrhaccountancysupport
# ioworkshops
# interenterpriseinformationexchangesystems
# johnsmithvehicleassetrepossessions
# justmarblene
# keithjonesprojectmanagement
# keypremier
# khheating
# kitchenrestorationsnortheast
# kitsonandsons
# lidian
# lotussilverstone
# lucypittaway
# marrowsmith
# mhttechnology
# mihaul
# mamgroup
# medicalpropertyconsultantservices
# melsonbypropertymanagement
# mercuryinternationalsolutions
# mercurymetalslondon
# merrinelectrical
# michaelblenchhaulage
# middlesbroughaccessconstructionspecialists
# milnerbros
# milnerecology
# miltonhouseyorkshire
# mirandabrockman
# momentumfinancialconsultants
# momentumfinancialpartnersllp
# momentumtaxationandaccountancy
# mudita
# mycreds
# nlengineeringservices
# natrium
# ncmconsultancy
# neptuneconsultancynortheast
# northernbarnesmedical
# northernrecords
# nsssecuritysolutions
# obsidiankeep
# orangemalone
# orbropeaccess
# pandjsampson
# paullyonsautomotive
# petercranshaw
# phoenixrefrigerationcatering
# pjmps
# planaheadfinancial
# planaheadproperties
# planetcitizens
# powersystemdesignservices
# projectprogrammeservices
# raorkney
# richardsonelectrical
# richmondsafetyservices
# roberthpearsonassociates
# rolandway
# rubiconsolutions
# rybrli
# solutions4logisitics
# southcroftforest
# spellmaninterimsolutions
# spivnslim
# sterlinghrsolutions
# sterlinginsight
# sterlingselection
# tjfarms
# tnaseby
# tdedevelopments
# teessidesoftwaresolutionsuk
# teessidetechnologyservices
# theactuarialrecruitmentpartnership
# theoldrectoryhurworth
# theplanet
# tomaldersonlanddrainagemachinery
# tonysimpson
# vitronicdevices
# wgblanchard
# we3brothers
# westfarmhawthorne
# workingtimes
# wwmedicalfacilities
# wwresidential
# wwtransitionalcare
# 512
# agriculture
# agrinomics
# fiveonetwowakefield
# tinylabs
# 52lemanstreetmanagementcompany
# arointernetbusinessdevelopment
# bainbridgemanagementco
# broughtonminerals
# cobnutwebservices
# cojonttrading
# cotterdalecottageholidays
# countykitchensleyburn
# creativerestorations
# gaylemilltrust
# highcotterdalesportingsociety
# konsoul
# mukershow
# northlawn
# oreillyhawes
# phkingsley
# pennygarth
# simonstonehallhotel
# simonstonehall
# simonstone
# stagsfell
# stanleyholdings
# stonehousehotel
# theconsultingchapter
# thecoverbridgeinn
# thefarmersarmsmuker
# theupperdalescommunitylandtrust
# theupperdalescommunitypartnershipudcp
# theupperwensleydalesportsandrecreationalassociation
# thewhiteharthawes
# twsimonstone
# uredalemill
# valeriemain
# valewest
# waltonsofhawes
# webbusteruk
# wellgarthcourtmanagementmasham
# wemmergillestatesllp
# wemmergillmoor
# wensleydaleland
# wensleydaleracing
# 56georgestreet
# assamrailwaysandtradingcompanylimitedthe
# atcomengineering
# atcomsystems
# balticuk
# beechwoodstrathtay
# broadlandenergydonich
# broadlandenergykiachnish
# broadlandenergylaudale
# broadlandenergymoy
# broadlandpropertiesconsultancy
# broadlandpropertiesestates
# broadlandproperties
# broadlandpropertiestrading
# broadlandrenewableconstruction
# broadlandrenewableenergy
# bronzerapid
# churchmeadowshb
# corlandsminerals
# countypropertiesnorthern
# countypropertiesgroup
# countyproperties
# hevercastlegolfclub
# hevercastle
# lowparkfarmebberston
# marshallestates
# newcavendishestates
# oakbrewerycompanylimitedthe
# operationgranitestone
# pavilionsquarescarborough
# pluspurepubliccompany
# rothleytempleestates
# saintdavidproperties
# seventyholds
# tailwindscarborough
# tailwindfilmproductions
# thescarboroughrocketshipcompany
# thesilverrocketshipcompany
# whiterosefinancecompany
# yorkdistrictinvestmentcompany
# 57southparadenorthallertonmanagementcompany
# abbeyparkampleforthmanagementcompany
# administrationservices
# allertonindustries
# allertonpropertymanagement
# associationoffencingindustries
# athelstanecrescentmanagementcompany
# bag2school
# bellevuedoncastermanagementcompany
# burwoodheightsmanagementcompany
# castlegatemowbrayparkmanagementcompany
# cathedralcourtmanagementcompany
# centurionfieldsadelmanagementcompany
# emmakerfootsladybirds
# fallowsparkmanagementcompany
# hambletonandrichmondshirecarerscentre
# healthcareforchildren
# herriothospicehomecare
# herriotpersonalcare
# libertygreenhullmanagementcompany
# lordswoodgrangemanagementcompany
# moorfieldsdanehillbradfordmanagementcompany
# nextbestclothingnorthallerton
# nextbestclothing
# omegabusinessvillagenorthallerton
# pavilionsquarephase2managementcompany
# pavilionsquarepocklingtonmanagementcompany
# phoenixandscoresbyparkmanagementcompany
# saerlysmountstreetflatsmanagement
# saffronparkmanagementcompany
# saxongatestamfordbridgemanagementcompany
# smartrecycling
# smarterrecycling
# stjohnscourtstanningleymanagementcompany
# stwilfridswalkmanagementcompany
# theassociationofnoiseconsultants
# thebeltopenspacemanagementco
# thechocolateworksmanagementcompany
# thegatewayhandsworthmanagementco
# thepasturesknaresboroughmanagementcompany
# thesidingshullmanagementcompany
# thetannerymanagementcompany
# tothenextlevel
# townsquarehorsforth
# trinitygatefinningleymanagement
# woodberrygrangemanagementcompany
# woodhallgrangemanagementcompany
# woodlandswalkbrantonmanagementcompany
# 58tachbrookstreet
# 5av
# 5thavenuefashions
# 6springhillterracemanagementcompany
# 6ddigital
# bluespikelandscapedesigns
# 6fifteen11
# cheesmanco
# dhprojectsolutions
# 6psconsultancy
# 7ladysmithavenuewhitbymanagementcompany
# 8ladysmithavenuewhitby
# saxonvillehotel
# 77wellingtonavenuemanagementco
# 7street
# ...
# richmondthermalsolutionssapcalculations
# vinylvisions
# richmondymca
# teessideestates
# richmondshirebuildingpreservationtrust
# richmondshireleisuretrust
# ridgewayprivatedaynursery
# ridingshomecare
# summerhouse
# rigworksengineering
# ripplemarkconsulting
# riskinfinity
# rispincouture
# ritecleanservices
# riversideeastern
# riversidegameandshooting
# riversideshooting
# scarboroughmeatsuppliers
# riverwoodproperties
# rjaywardracing
# rjmagronomy
# rjsjoinery
# rmarail
# rmbweldingservices
# rmcmdevelopments
# rmlmarineinspectionservices
# stephenpickeringtraditionalbuildingservices
# rngdraughtingservices
# rnrpowdercoating
# roadsidedevelopmentsyorkshire
# robheapconsulting
# robpetchebuilders
# robshawconsulting
# robertdonnell
# roberthalldecorating
# robertlaycock
# robertross
# roberts66
# thesimfevershamcovertsllp
# robinhoodsbayartsgroupcic
# rymerdevelopments
# robinsonsjet
# robsonfenwick
# rockhoppercoffee
# rodbersofrichmond
# roderickhuntlegalservices
# rogermacdonaldconsultancy
# rohanwoodworking
# rollingrestorations
# vickyannisphysiotherapy
# romatrading
# rondor
# roofwrap
# rootwise
# roperscaravanworldcatterick
# ropersleisure
# ropersproperty
# ropner
# thorpperrowarboretum
# rorykemp
# rosebunch
# roseberrycontractservices
# ssoffshoreservices
# rosedaleconsulting
# rosedaledevelopments
# rosewoodcourtresidentsmanagementcompany
# uniquegiftsinternational
# rosewooddentalclinic
# rosspaxton
# rougeinvestments
# totalstainless
# rountonsvillagehall
# rowanmanagementco
# rowantreegardendesign
# taalco
# rowellsgentshairdressers
# rowlandjayneproperties
# stubbsinspectionservices
# rpscivilengineering
# rsgildroy
# walterboyeswhitby
# rsgconsultants
# rssyorkshire
# rtwroadrestoration
# yorkshireweddingbarn
# rubyriversboutique
# rueburyconsultants
# tristansillars
# rugbypropertyinvestments
# rumblingtums
# rupertdruryco
# russellskirbymoorside
# rustyshears
# trattles
# ruswarpminiaturerailway
# turnerdale
# ruthgordonassociates
# rutlandrtmcompany
# rvelectricalservicesscarborough
# rwconsultancyservices
# rwsbodyworks
# teamengineeringne
# yorkshirevanlease
# ryecatenterprises
# ryecat
# ryechem
# ryedaleaesthetics
# setscenic
# ryedalearchaeologyservices
# ryedaleclaypidgeonclub
# ryedaledomesticenergyassessors
# yorkshirelaundryservices
# ryedalegarages1946
# ryedalemotorcycleclub
# ryedaleplumbers
# ryedalesocietyofmodelengineers
# ryedalevintners
# tatesmith
# ryedaleymca
# rypasocialcare
# waterhouselane
# sdinstallationsyorkshire
# sdinspectionservices
# theukchristmasstore
# sebentleyconsultancy
# sgmclements
# spdevelopmentsyork
# tdctrading
# saanthony
# thehillcrossorganisation
# sdtindall
# sgarthengineering
# shawpropertydevelopments
# teesvalleyhealth
# sgosneygunsmith
# sgreenwhitby
# slcoverings
# sms
# splabourcontractservices
# sptechnicalinspection
# swaindsons
# thedispensingdoctorsassociation
# shuntley
# sswalesjoinery
# tafreeman
# s2lr
# sadiebelleaesthetics
# safetypointsigns
# saggersgold
# sailsby
# saintcatherineshospicelottery
# saintcatherineshospicetrust
# scarboroughhospicesales
# simplyyorkshire
# theguildoflillians
# salonsspasetc
# samsonblack
# samuelblack
# thehawesfarmersauctionmartcompany
# sandersongroundcare
# sandgateseafoods
# whitbyglass
# sandhuttonfarmproduce
# sandringhamconsultancyservices
# sandsendcourtmanagementco
# sandsendstoreswhitby
# tidesbeachshop
# sandsendstores
# sandwathcontracting
# sarahannjewellers
# savage
# savannawindows
# save9consulting
# save9
# saywellsubseaservicies
# sbbuildingcontractors
# scottphillipsconsultancy
# vue3sixty
# sbaelectrical
# scprojex
# scalbymillinn
# startersandsweets
# scampstonconservatorypreservationcompany
# scampstonfarmingcompany
# scampstonsporting
# stquintininvestments
# scanwrightndt
# scarboroughanddistrictcitizensadvicebureau
# scarboroughandryedalecommunityhealthandsocialcarepartnershipcic
# scarboroughandryedalecommunitycyclingcic
# scarboroughapartments
# seaviewapartments
# scarboroughcarauctions
# scarboroughcounsellingpsychotherapytraininginstitute
# scarboroughflowerfundhomes
# scarboroughhandcarwash
# scarboroughnorthcliffgolfclubthe
# scarboroughnorthcliffgolfclubtradingcompany
# scarboroughpleasuresteamersregallady
# scarboroughrugbyunionfootballclub
# srufcsilverroyd
# scarboroughsouthcliffgolfclub
# scarboroughsouthclifftrading
# scarboroughstudios
# scarboroughtrading
# scarboroughutc
# scarboroughweightliftingclub
# scarboroughwhitbyandryedalemind
# scholarsbar
# theinclusionzone
# schooloftheatredance
# schroedingergroup
# scifiscarborough
# scitusmanagement
# scopetime
# scotfir
# scotiaconstructionmanagementservices
# scotsdikemanagementcompanyblockc
# swalevalleyconstruction
# scottcontractcommercialconsultancy
# scottmiller
# scottsgreys
# scotthamlin
# seacology
# seadriftcafe
# seagrown
# seanconnolly
# seasonedproductions
# seasonseast
# seeandtreat
# seekingswardlefinancialservices
# seismicservices
# selectelectricalcontrols
# thedogbackpacker
# serendipity29
# serrehbunsimportandexport
# servingsport
# sestontransport
# seymourinman
# spiderwebinternet
# vandalsleisureandretail
# shcontracting
# shprecisionengineering
# shaunashtondesign
# shb
# shab1
# sharadaraj
# testingrainmaker
# sharpbusinessservices
# sharpcatering
# shaunasimpsondevelopments
# sheddenfarms
# valerieclaydeneducationalservices
# shellycallyschildminding
# shematan
# shemonshippinganddistributioncompany
# shirehaven
# shorthorn
# shrapnol
# sidbrackleybuilders
# sidwattsplumbingandheating
# sigmatoe
# wallacenedley
# willink
# silverstreetmanagementproperties
# simonbecky
# smccorporatesponsorshipservices
# simonmuirbuildingcontractors
# simplyipsolutions
# simpsonandassociates
# simpsonbusinesssolutions
# slbathrooms
# sirusconsulting
# sitewelduk
# sixvalleylambllp
# thechillijamman
# thechillijammanstreetfood
# therobertfullergallery
# sjprocurement
# skills2saveuk
# skmnorthern
# skutterskelfeanglers
# steadyawaypigs
# skybluesteve
# smallways
# smardalehouseresidentsassociation
# smartpropertycare
# smarttechcontrolsystems
# smartiesboutique
# smcfish
# smithconsultants
# smrsafety
# sneakyleaks
# solaireheatingproducts
# solairequartz
# solohr
# solocad
# vprocessdesign
# sonidorsequestrian
# sonidors
# soscuba
# sourbeckford
# southparadeamenitywoodland
# wholeofthemoon
# southshorechaletsbridlington
# southdenefileymanagementcompany
# thelookoutmanagementcompany
# spahousehealthandbeauty
# spane
# spacelux
# vistafacilities
# spacesoft
# sparkiesparescom
# stitchesinteriors
# sparrowhairandbeauty
# victoriagoldentandoori
# sparrowhawkstampllp
# spcspares
# specialsendoffs
# specialistdents
# specialistsurgicalcare
# spectrumtiles
# spencerandwards
# spenrigg
# spensound
# spinboson
# spodesphaggott
# sportsmansclubnorthallerton
# springfieldfarmssherburn
# springfieldgaragethirsk
# springwellmanagementcompany
# spudagronomyconsultancy
# spurgingham
# squad51
# squarecherries
# squeezernet
# squireofscarborough
# sstplant
# stconsultingeurope
# stjameslandscapes
# stjamespropertymanagement
# stagsfellcourtmanagementcompany
# stairsandmore
# stanleygrangeshowteam
# stanleysproperties
# starfishinformationproducts
# thinksmartlogistics
# starlightembroidery
# whitbyanddistrictcommunitytransport
# whitbycoastalcruises
# stationtaxisnorton
# tpharding
# stationarymovement
# steelcitygaming
# stephencoxndt
# stephenlee
# stephentuerfarms
# stepneyhillfarm
# steveclarkelectrical
# stevegoodchild
# theengravingcompany
# steveowenttp
# stevepeckover
# stevenbowes
# stevenjdresserelectricalcontractors
# stevenjdresserholdings
# stirred
# stockdaleconstruction
# stokesleybrewingcompany
# stokesleygolfrange
# stokesleykitchens
# stokesleymasonichall
# stolricrsmith
# stoneswestheslerton
# stonetrax
# storeriteservices
# turnersfabrications
# stoutaccountancy
# straightshooters
# strawbeck
# streetsaheaditbusinesstechnology
# stuartyoungconstruction
# stubbsfarming
# sturmansantiques
# stylenowmedia
# subseaandmarineconsultancyservices
# wiganthorpecourtmanagementcompany
# subtiliterconsulting
# suddabys
# sudek
# sumsitup
# sunguard
# talbotcarcare
# topnoteevents
# superskills
# suresmart
# sustainablerisksolutions
# sutcliffewallace
# sutherlandrenovations
# suttonfarmmanagementcompany
# suttonontheforestpubcic
# swaleautosalesii
# swaleautosales
# swaleviewcaravansales
# swalevalleyspringwater
# swaledalehomes
# swaledaleoutdoors
# swaleshore
# swallowholmcottagesmanagementcompany
# swanjewellerycompany
# swiftfoundations
# treehouses
# swimperfect
# tghharper
# syloclean
# syndron
# synergiefireandsecuritysolutions
# synthesifit
# szfagrotrading
# tforsythbuildingservices
# tmasonservices
# twporrittson
# tweaverplanthire
# tklandscapes
# tbearlefarmslimited
# tcwing
# tpatkinson
# tsuka210992
# tajmahaal
# therichmondchocolatecompany
# tamebridgeresidents
# thestablescourtyardmanagementcompany
# tamivonga
# tancream
# thorntonlodgecountryretreats
# thorntonlodgecountrysports
# tancredgravel
# tanfieldmillmanagementcompany
# tantalisetanning
# tarnhelmsecurities
# tateexplorationconsultants
# trekoverland
# taxjet
# taylorwyndley
# taylorsfootballsouvenirs
# taymech
# teampubsandbars
# tearewoodsluxuryicecream
# thebuckinnwhitby
# techkit
# techknowledgyconsulting
# technicalp
# whitbycrabcompany
# teesqualityconsultants
# teesvalleygroundworks
# teessidetruckexport
# telecomyorkshire
# templetonpublishing
# tenigowensleydale
# wensleydaleicecream
# tennantconstructionuk
# tennantsevents
# tennantsofyorkshireantiqueandfineartauctioneers
# tenzingtraining
# terringtonhalltrust
# testcarddiagnostics
# thespencewolrichpartnership
# thealmaphoenix
# thearcheswhitby
# theartisansausagecompany
# theballoontreeyorkshire
# thebayfront
# thebayhorsecrakehall
# thebeckveterinarypractice
# thebestofcrete
# thebluebellinnweaverthorpe
# theboltonarmsredmire
# thebondgatepractice
# thebraclinic
# thebridgeinnruswarp
# thewillowbranchwhitby
# thebuckinngoodpub
# thec10debcompany
# thecaptainstablehunmanby
# thecarltoninn2012
# thecatsmeow
# yoremillcraftshop
# thecharlesruddocktrust
# theclevelandgarage
# thecopperkettlereeth
# thecroftpropertyco
# thedalessweep
# themashamshiremiddlehamanddistrictyouthchildrensproject
# thedarkplace
# thedentalhealthpractice
# thederwenthunt
# thediamondnetworkne
# theemporiumtrading
# theforumnorthallerton
# thefredharpermemorialtrust
# thefuzzydogbakery
# thegilchristcompanyuk
# thegreengrocerthirsk
# thegroovymooicecreamco
# thehoustonconsultinggroup
# thehusthwaiteorchardvillage
# theitilhub
# thekirkbyfoundation
# thelandingsmanagementfiley
# thelbddietplan
# theleftbehind
# theleyburnlivestockauctionmartcompany
# thelilacpartnership
# themarblepress
# themercuryhousingco
# themowingmanllp
# themusepartycompany
# veinart
# thenationalschoolhawescic
# thenewtoncerealcompany
# thenorthyorkshirepubcompany
# theoasismondays
# theoldmanseguesthouse
# theoldmeetinghousetrust
# theoliviapartnershipllp
# theorangetreerelaxationcentre
# theorganicfarm
# theparkathovingham
# theperformanceculture
# thepiepubcompany
# theploughinnsleights
# theportholefoundation
# theprinters
# thepyjamahouse
# therestorationcompanynorthyorkshire
# theretroemporium
# thesecretpirate
# theshipwhitby
# whitbygiftshop
# thesizzlinggriddle2017
# thetophousefiley2017llp
# thestableshunmanby
# thestarfiley
# thestationinn
# thestonetroughinn
# thestoreyfarmpartnership
# thetannerynorton
# thethinklightplatform
# thinklighttheatre
# thetoolbagcompany
# thetpmengineeringgroup
# thetravellounge
# thetreesstaithesmanagementcompany
# theviscountbuscoachcompany
# thewalkingshop
# theweaversgreenmanagementcompany
# thewellnesstreeretreat
# thewildgoldcompany
# theyorkmint
# thewildlifehavenrescueandrehabilitationcentre
# thewoodstreetmanagementcompanynorton
# thewoodenhorsenursery
# thewoodlandsacademyscarborough
# theyorkshiregleamteam
# thezetlandhunt
# the3muses
# thecitysecret
# theukweddingdirectory
# thirdenergyonshore
# thirdenergytrading
# thirdenergyukgas
# thirskfurnitureproducts
# thirskfurnitureproperties
# thirskpowdercoating
# visionpvc
# wwraluminium
# thirskracecourse
# thirsktouristinformation
# thirsk8park
# thirty6restaurantgroup
# thisisgroup
# thomasofyork
# thompsonandmoon
# wanxinghong
# thompsonbuildingcontractors
# thompsonshardware
# worthypearson
# thormanbyenergy
# thorntonfinancialplanning
# thorpeco
# thorpefieldpartnership
# threedogdrilling
# whitbycaravanpark
# throughclouds
# thtenterprises
# tibbettproperty
# tillotsondevelopments
# titanresourcemanagement
# tjshairsalon
# tjaescleaningservice
# tjsplumbingservices
# tkyhealthcare
# tldlettings
# toddplas
# tollertonhealthservices
# tollertonstores
# tomangroup
# tonybarneselectricalcontractor
# tonytaylor
# tonysices
# topbananapublishing
# topspothousing
# totalinteriorcontracts
# tourismuk
# towlersproperties
# townandcountryblinds
# tpfimagesarts
# tracetechuk
# traceyhilltrainingandconsultancy
# tractionpowerservices
# tradesuites
# trainingwithintellect
# tredrayelectricalcontracting
# treeconiferremoval
# yorkshirestumpgrinders
# treskeholdings
# trevorwatsonassociates
# tridenteducationsolutions
# tridentmarketingsolutions
# tridenttechnology
# trinitychurchcourt
# tripility
# triplestraining
# triptec
# trucktechnics
# truckingjobscouk
# trulyscrumptiouswhitby
# trvlnation
# tswbusinessdevelopment
# tudoreatinghouse
# tuldia
# turnerspersonalcredit
# turnstileassociates
# tuttiorganics
# tweedshotgundogs
# twistedautomotive
# twistedip
# twistedperformance
# twistedpaircommunications
# twrc
# wensleydalerailwayassociationtrust
# wensleydalerailwayassociation
# wensleydalerailwayplc
# wrcp
# tyralaproperty
# uhire
# ufoleisure
# ugthorpecaravanpark
# ukcanine
# ukdirectdevelopments
# ukpods
# ukrally
# ultimatesoccerschool
# unconventionaldesign
# undergroundparts
# unicornrichmond
# unionmillwhitby
# uniquename
# unitedservicesyorkshire
# upex
# upmraflatacuk
# upperwensleydaleindustrialandprovidentsociety
# usherinlaw
# vsangalang
# valeadventures
# valentinecolettings
# vanbelle
# vanillablackenterprises
# verdantmanagementservices
# vetrosolutions
# vicaragefarmmanagement
# vickyanderson
# vickymiley
# wizzywoo
# villagefarmllp
# villandroproperties
# vinestreetmetals
# vinegarsco
# vintagehotelllp
# vision4
# vistechteam
# vivahair2012
# volumeye
# vtmfabrications
# vtsdesignwebservices
# vtshosting
# vuepoint
# vyasconsultancy
# wgpetherick
# whazelljoinery
# wmgarbutt
# wmetcalfesons
# ylproducts
# wtaviation
# whodgsonpartners
# wnuttson
# waalmack
# woalderson
# wtc360
# wackersmotherhubbards
# waddingtonbuildings
# waddingtonwrightproperty
# wadsworthcapital
# wah2003
# walcoteconsultants
# waldow
# walkfarmeggs
# walkersfishrestauranteastayton
# wallbrothersyorkshire
# wallacefabrications
# walterpickering
# wardrenewablesenergy
# wardmanfarming
# warwickcourtmanagementscarborough
# wastetrainingconsultancy
# watchmanfilms
# watergatehaulage
# wathgillpetservices
# watkinswrightboroughbridge
# watkinswrightkirkbymoorside
# watkinswright
# yorkshiredeals
# watsonconstructionfiley
# watsonsofbrandsby
# wattspdc
# weblinks
# webstersfarmers
# wedgwoodandharrison
# weemsyconsultancy
# welbecktransport
# welhamparktroutfarmmalton
# welhamparktroutfarms
# wellsfield
# wensleydalepayroll
# wensleydaletreeandhorticulturalservices
# wesconsultancy
# wesconsultancyllp
# wesrealestatellp
# yorkshiremoorsmeat
# wespace
# westcountrydesignandbuild
# westhillvc
# westsquare1965
# westtanfieldluxurylodges
# westtanfieldluxurylodgesmanagement
# westtanfieldluxurylodgesrental
# westfieldoriginals
# westholmecommercialservices
# westpointenvironmental
# weydalemanor
# wgsconsulting
# whataview
# wherethejobsare
# whitbydistrictfishingindustrytrainingschool
# whitbyfishingtrips
# whitbygetawayscatering
# whitbygetaways
# whitbygolfclub
# whitcliffegrange
# whiteheartmarketing
# whitepointcourtmanagementcompany
# whiterosesports
# whitehallderwent
# whitworthsolutions
# zeusmanagementsolutions
# whorltonengineeringservices
# widdyfields
# wildandexotic
# wildpork
# wilfredscruton
# wilkinsonsportsandleisure
# williamandersonfarmers
# williamsco
# willoughbyrose
# willowenvironmentalsolutions
# wilmotearlyyearsandeducationconsultancy
# wilsonbisolutions
# wilsonpetch
# windsorbellinternational
# winkfieldsolidfuel
# winnscoaches
# wittonsporting
# wizardbuilders
# wjfengineering
# wkf98
# wlarb
# wmcommercialsandagriculturaldealers
# wnwr
# woldtoptransportmanagement
# woldelveproperties
# woldsstoves
# woodcockmanagementservices
# woodendautoplantservices
# woodhouseplumbingheating
# woodlanddesignservices
# woodlandsvalemanagementcompany
# worldgrandmastersassociationwgma
# worldmacinternational
# wratravel
# wrenaccountingandtax
# wrestbuilders
# wrightresources
# wrightsseadalecaravancamp
# wrtelectricalsolutions
# yarrow
# yellowwellies
# yendallcommissioning
# yny
# yo318
# yorbrand
# yorkcityproperties
# yorkheritagethehallthorntonledale
# yorkheritage
# yorktransmissionsupplies
# yorkwinessheriffhutton
# yorkshirebarsolutions
# yorkshirebuildingcompanynyorks
# yorkshirechangeconsultants
# yorkshirecoasthomes
# yorkshiredalesbuildingconsultancy
# yorkshiredalesmeatcompany
# yorkshiredalesriverstrust
# yorkshiredroneservices
# yorkshireendeavouracademytrust
# yorkshireenginesupplies
# yorkshirefatigueclinic
# yorkshiregashomefuels
# yorkshireglidingclubproprietary
# yorkshirehotels
# yorkshirelifefinancialservices
# yorkshirelifemortgages
# yorkshirelifeprotection
# yorkshireplants
# yorkshiretrees
# yorkshirerisksolutions
# yorlox
# yorukoglu
# younglinxevents
# zafirahmed
# zafranhorseshelptoheal
# zammerdigital
# zenithpower
# zingsongsproductions
# zukis

# %%
ch_nyer.loc[index,'website_2']
# Out:
# 'Website not found'

# %%
# Retrieve websites for each company with a for loop
for index, row in ch_nyer.iterrows():
    if pd.notnull(row[30]) == True:
        continue
    ch_nyer.loc[index,'website_2'] = return_website(standardise(row[0]),row[7]) 
    ch_nyer.loc[index, 'sm_2'] = str(get_social_media(ch_nyer.loc[index,'website_2']))
    print(str(index) + ' - ' + str(row[0]) + ' - ' + str(ch_nyer.loc[index,'website_2']) + ' - ' + str(ch_nyer.loc[index,'sm_2']))
    sleep(0.001)

# %%
ch_nyer.to_csv('ch_nyer_website_sm_2.csv')

# %% [markdown]
# ## Scraping social media accounts

# %% [markdown]
# Now that we have the websites from Google Places, we can scrape social media accounts and other interesting sites (i.e. trip advisor) for these and then subsequently scrape activity, and follower information from those.

# %% [markdown]
# Let's import our NYER dataset from the previous section.

# %%
import os
cwd = os.getcwd()
print(cwd)
# Out:
# /Users/dataexploitationmac1/Desktop/Faisal/companies-house

# %%
nyer = pd.read_csv('nyer_with_websites.csv', index_col=0)

# %%
nyer_websites = nyer[nyer['website'] != 'Website not found'] # select those with websites

# %%
nyer_websites.head(10)

# %% [markdown]
# Choosing 'AUTO 66 RACING LIMITED', with crn 00980520 for our test as this has social media handles.

# %%
auto = nyer_websites[nyer_websites['crn'] == '00980520']

# %%
auto

# %%
print(auto.website.values) # website

# %% [markdown]
# Python package exists to extract social media: https://pypi.python.org/pypi/extract-social-media/0.4.0. Can also used regex: https://github.com/lorey/social-media-profiles-regexs. We'll test the package for now.

# %%
# Code copied and pasted from above link
import requests
from html_to_etree import parse_html_bytes
from extract_social_media import find_links_tree # install first with setup.py from link above

# %%
res = requests.get('http://www.oliversmountracing.com/')
tree = parse_html_bytes(res.content, res.headers.get('content-type'))

# %%
set(find_links_tree(tree))
# Out:
# {'https://twitter.com/auto66racing',
#  'https://www.facebook.com/oliversmountracing',
#  'https://www.instagram.com/oliversmountracing/',
#  'https://www.youtube.com/user/oliversmountracing'}

# %% [markdown]
# Wrapping this up in a function

# %%
def get_social_media(url):
    '''
    Retrieve social media accounts from a company website
    Input: string of URL
    Output: dictionary of links
    '''
    try:
        res = requests.get(url)
        tree = parse_html_bytes(res.content, res.headers.get('content-type'))
        if len(set(find_links_tree(tree))) > 0:
            return set(find_links_tree(tree))
    except:
        return 'Not found'

# %%
get_social_media(ch_nyer.loc[26,'website_2'])
# Out:
# {'https://twitter.com/auto66racing',
#  'https://www.facebook.com/oliversmountracing',
#  'https://www.instagram.com/oliversmountracing/',
#  'https://www.youtube.com/user/oliversmountracing'}

# %%
get_social_media('http://www.oliversmountracing.com/')
# Out:
# {'https://twitter.com/auto66racing',
#  'https://www.facebook.com/oliversmountracing',
#  'https://www.instagram.com/oliversmountracing/',
#  'https://www.youtube.com/user/oliversmountracing'}

# %%
nyer_websites.website

# %% [markdown]
# Running this on dataset (took about an hour to run)

# %%
nyer['social_media'] = nyer.website.apply(get_social_media)

# %% [markdown]
# ### Getting twitter followers

# %%
nyer_websites.head()

# %%
nyer.social_media.head(100)

# %%
nyer_sm = nyer[(nyer['social_media'] != 'Not found') & (nyer['social_media'] != {})] # select those with websites

# %%
nyer_sm.social_media

# %%
nyer_sm.social_media.isnull().sum()

# %%
nyer.head()

# %%
nyer.to_csv('nyer_with_websites_sm.csv')
